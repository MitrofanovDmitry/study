# %% [markdown]
# ### Anagrams & Palindromes

# %%
import itertools
import collections

# %%
words = []
for line in open('words.txt','r'):
    words.append(line)

# %%
len(words)
# Out:
# 172820

# %%
words[:10]
# Out:
# ['aa\n',
#  'aah\n',
#  'aahed\n',
#  'aahing\n',
#  'aahs\n',
#  'aal\n',
#  'aalii\n',
#  'aaliis\n',
#  'aals\n',
#  'aardvark\n']

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron\n'.strip().lower()
# Out:
# 'aaron'

# %%
words = []
for line in open('words.txt','r'):
    words.append(line.strip().lower())

# %%
words[:10]
# Out:
# ['aa',
#  'aah',
#  'aahed',
#  'aahing',
#  'aahs',
#  'aal',
#  'aalii',
#  'aaliis',
#  'aals',
#  'aardvark']

# %%
words = set()
for line in open('words.txt','r'):
    words.add(line.strip().lower())

# %%
words = {line.strip().lower() for line in open('words.txt','r')}

# %%
words = sorted({line.strip().lower() for line in open('words.txt','r')})

# %%
sorted('aaron')
# Out:
# ['a', 'a', 'n', 'o', 'r']

# %%
sorted('elvis') == sorted('lives')
# Out:
# True

# %%
''.join(sorted('aaron'))
# Out:
# 'aanor'

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
def find_anagram(myword):
    mysig = signature(myword)
    for word in words:
        if mysig == signature(word):
            print(word)

# %%
find_anagram('dictionary')
# Out:
# dictionary
# indicatory

# %%
# %time find_anagram('dcitionary')
# Out:
# dictionary
# indicatory
# CPU times: user 125 ms, sys: 9 µs, total: 125 ms
# Wall time: 123 ms

# %%
words_by_sig = collections.defaultdict(set)

for word in words: 
    words_by_sig[signature(word)].add(word)

# %%
anagrams_by_sig = {sig: wordset for sig, wordset in words_by_sig.items() if len(wordset) > 1}

# %%
def find_anagram_fast(myword):
    sig = signature(myword)
    return anagrams_by_sig[sig]

# %%
find_anagram_fast('tops')
# Out:
# {'opts', 'post', 'pots', 'spot', 'stop', 'tops'}

# %%
find_anagram_fast('Michele')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-6461e530a6a0> in <module>
# ----> 1 find_anagram_fast('Michele')
#
# <ipython-input-57-f434ae24cec1> in find_anagram_fast(myword)
#       1 def find_anagram_fast(myword):
#       2     sig = signature(myword)
# ----> 3     return anagrams_by_sig[sig]
#
# KeyError: 'Mceehil'

# %%
 def find_anagram_fast(myword):
        sig = signature(myword)
        try:
            return anagrams_by_sig[sig]
        except KeyError:
            return set()

# %%
find_anagram_fast('Michele')
# Out:
# set()

# %%
# %time find_anagram_fast('Michele')
# Out:
# CPU times: user 12 µs, sys: 1 µs, total: 13 µs
# Wall time: 15.7 µs
# set()

# %%
sorted(anagrams_by_sig.keys(), key=len, reverse=True)
# Out:
# ['aceghhiimooopprrst',
#  'aacghhiilloooppsty',
#  'aaadeghiiooprrstu',
#  'accghhiimooopprrt',
#  'aeghhiiloooppssty',
#  'aeeeghhiloopprstt',
#  'aaacdghiiooprrtu',
#  'aaceghhmooprrrst',
#  'deeflnooprsssstu',
#  'beeiiiiilmprssst',
#  'eeeeiimnprsssssv',
#  'acghhimooopprrst',
#  'acghhimooopprrty',
#  'acghhiiloooppsty',
#  'aacghiilllmorty',
#  'aeeeeinnssstttv',
#  'aaadghiooprrstu',
#  'aaadghiooprrtuy',
#  'aaceghhmooprrrt',
#  'acceeegilmnortt',
#  'acghhimooopprrt',
#  'aghhiloooppstyy',
#  'aeeghhloopprtty',
#  'aeeeelnsssssstt',
#  'acehiinnoprsst',
#  'aaadghiooprrtu',
#  'accefiiinorstt',
#  'aceeghhooprrrs',
#  'aaceilnnoorstv',
#  'aceeinoorrsstv',
#  'acdiilnnooosst',
#  'aceeeeinrssstv',
#  'deeghilmoortyz',
#  'deeeiimnorsstt',
#  'cdeeeeinrsssst',
#  'acdiiimnorrsst',
#  'adegiiinnorstt',
#  'acceegillnorty',
#  'acfgiiiilnnost',
#  'beiiiilmprssty',
#  'eiiimmnoprssss',
#  'eeeiimnprssssv',
#  'cdeeeiinnrssst',
#  'aeegiinorrsttv',
#  'aaaacdiillprsy',
#  'eeeinoprssssuv',
#  'cceeinooprsssu',
#  'eiinoopprssstu',
#  'abefllnoopsstu',
#  'acceemnorsttu',
#  'aceeiilnorstt',
#  'aabdeiiilorst',
#  'aaceiilnprstt',
#  'aceeiinnorsst',
#  'aeefginorrstu',
#  'aeeeinnsstttv',
#  'aabdgiilnorss',
#  'abhiikmnnprss',
#  'aaaaceinrrssv',
#  'acceehilmoprt',
#  'accefiiinortt',
#  'achiilnnoorst',
#  'aceeghhooprrr',
#  'aciiilnoosstt',
#  'acceiilmmorst',
#  'ceiimmnoorsss',
#  'acceeinnorssv',
#  'aceinnoorsstv',
#  'aceeinoorrstv',
#  'acdeeiinnorst',
#  'aceeiinorrstt',
#  'acddeemnnortu',
#  'aceinnorssttu',
#  'acdiiimnorrst',
#  'aeiilnoopsttx',
#  'adeefnorrsssw',
#  'aeeehlnpsssss',
#  'eefhlnrssstuu',
#  'ceefiimnoprst',
#  'aegiimnnoprst',
#  'eiiimmnoprsss',
#  'aaciiinnosttv',
#  'aaceiilnnortt',
#  'ceeinooprrstt',
#  'cceefiiinprst',
#  'eeilnoooprrst',
#  'aaegiiilmnrst',
#  'eghilnooprsst',
#  'acdeeinoortuv',
#  'aceeinorsssuv',
#  'aceiilnoprsst',
#  'aeehilmnnopst',
#  'aeghhoopprrst',
#  'aeegiinnorrtt',
#  'aehiilnoprsst',
#  'eeeghnnrrsstt',
#  'eeinnorssssuu',
#  'aeeelnssssstt',
#  'acefiiinorstv',
#  'accdiinoorst',
#  'acceemnorttu',
#  'aadegilnrttu',
#  'aaceilnorstt',
#  'aacceinnorst',
#  'aacdeilmnost',
#  'aiimnooqsttu',
#  'aeiilnnosttv',
#  'acehooprrsst',
#  'abcceiinorst',
#  'aabdeilorrst',
#  'abehiimorssv',
#  'aabdgiilnors',
#  'aabcdeorrsst',
#  'achiimnorsst',
#  'aciiilnoostt',
#  'aciillnoosst',
#  'cdeiimmnooss',
#  'ceiimmnoorss',
#  'cceeginnnort',
#  'ccegiinnortz',
#  'cdeiinnoorst',
#  'aceinnoorstv',
#  'acdeilnoosst',
#  'ceimnorssstu',
#  'ceennoorrsst',
#  'cdeemnoortuv',
#  'ceeinoprsstu',
#  'aceinnorsttu',
#  'aceiimnorsst',
#  'aceeeinrsstv',
#  'aceeiiirsttv',
#  'aceeilnnorst',
#  'cehmoossstuu',
#  'acdefiiinost',
#  'deeeimnorstt',
#  'adeiilnoopst',
#  'adeegmmoprrr',
#  'aadeiilnortv',
#  'aadeiilnnost',
#  'deeeiinrsstz',
#  'adegiilnprsy',
#  'adeeimnnrstt',
#  'abdeeiilrstz',
#  'acdeeinoprtu',
#  'adeiilnorsst',
#  'adehhioppsst',
#  'cdeeeinrssst',
#  'cdeeimnnrsst',
#  'adeeeimprstt',
#  'diiiimnosssv',
#  'acdeiimnorst',
#  'aeeehinrssst',
#  'aeeeinrssstw',
#  'bdeeeimorrrs',
#  'aacehillmpty',
#  'aeegiinnnrtt',
#  'acehiinssttu',
#  'aeeimnnorstu',
#  'cceehinnortt',
#  'abeefgilrsss',
#  'aagilnorsttu',
#  'eeeeegknprrs',
#  'aabdehhirrst',
#  'aabddehhnrst',
#  'eehhmoorsstu',
#  'aeehinoprstu',
#  'aeiilmmorsst',
#  'adeeimnoprst',
#  'aceiimnoprst',
#  'eeiilmprssvy',
#  'aacgiiinnttv',
#  'aaciiinnottv',
#  'ceiinnnosstt',
#  'aceinooprrst',
#  'cdeiiinnorst',
#  'cdeeiilnrsty',
#  'aefiinnosstt',
#  'aciilnnoostu',
#  'aeiimnnorsst',
#  'ceeinorrssst',
#  'eeeinprrrstt',
#  'aeiinnorsttt',
#  'eeeiinrrstvw',
#  'aceeiilnorst',
#  'ceeiilmrstuv',
#  'aeghhmoprrty',
#  'aceeilnoprss',
#  'eeghilnooprs',
#  'eghilnooprst',
#  'ceeeilnnostv',
#  'abcinorssttu',
#  'aaaacdiilprs',
#  'aeiinoprrstt',
#  'aeenoprrsstt',
#  'aeeinnoprstt',
#  'aceeiipprstt',
#  'eeinoprsssuv',
#  'ccehinoprsty',
#  'ehhiilooppss',
#  'aeghhoopprrt',
#  'cghiloopssty',
#  'aceilnopsstu',
#  'aeinooprsttt',
#  'aacgiimprstt',
#  'deegiinoprst',
#  'ceeeilnoprst',
#  'abeinooprrst',
#  'eiinooprrssv',
#  'ceghiloopssy',
#  'aaeiilnorstz',
#  'ceeinnoorrst',
#  'adeeeginrrtt',
#  'aegiiilnrtvz',
#  'eeeghnnrrstt',
#  'aefmnorrrsst',
#  'eehloprrsstu',
#  'egiilmoossst',
#  'eeeimnorsstt',
#  'eeinoprssssu',
#  'aeehinssssty',
#  'aeflnoopsstu',
#  'ceeiimorsstv',
#  'aabceeinrrs',
#  'acceeiorsss',
#  'aacdeiilnst',
#  'acdeeiimrst',
#  'aaciinosttv',
#  'adiimnnoost',
#  'aabdiilorty',
#  'adeenrrstuv',
#  'aeimnoorsst',
#  'acghiilmort',
#  'aaeiilnnost',
#  'aeeeiklnsss',
#  'aegillorsst',
#  'aadiillnttu',
#  'aceeiinnrst',
#  'aaeghmnoprs',
#  'aeeginnrsss',
#  'aadeimnrstv',
#  'aaginnosstt',
#  'aeghilnoost',
#  'aacfiimnsst',
#  'aeilnoprsty',
#  'aeiiilmnsst',
#  'adeimnnorst',
#  'aaiilmnnost',
#  'aahiinprsst',
#  'aceiinprtty',
#  'aagiinnqttu',
#  'aceiinpsstt',
#  'adehiorrsst',
#  'acehooprrst',
#  'aeiillrrstt',
#  'aacdeeinrst',
#  'aceimorrstt',
#  'aeeilntttvy',
#  'abcceiinort',
#  'abekkorsstw',
#  'abehiimorsv',
#  'abdeeiilstz',
#  'abelooprsst',
#  'abdeehirstw',
#  'aabcdeorrst',
#  'abccinorstu',
#  'aacghillpry',
#  'aaciillprty',
#  'acdeinoorst',
#  'aceeinprrst',
#  'aacggilnotu',
#  'aceeinssstt',
#  'acdeeilnrst',
#  'aceeilnrsst',
#  'abceefiilrt',
#  'acdeehilnrs',
#  'achiimnorst',
#  'cehilorssty',
#  'cdeeiiimnst',
#  'cefgiinnorr',
#  'aciillnoost',
#  'acceilmopst',
#  'ccdeeennort',
#  'cceinnoorst',
#  'ccdeeinortz',
#  'cceeinorstz',
#  'cddeiinnoot',
#  'cdeiinnoort',
#  'accennorsvy',
#  'acdeeinorst',
#  'acceinnosst',
#  'ccdenorsttu',
#  'ceimnorsstu',
#  'aceennorstv',
#  'cdeeiiorrst',
#  'ceeiknorsss',
#  'ceennoorrst',
#  'acceiimnost',
#  'aceilnortuv',
#  'aceiimnorst',
#  'aceiinorstt',
#  'aceeilnnort',
#  'ccddeeenors',
#  'aceimoprrty',
#  'cehilnosssu',
#  'adegilnnrss',
#  'adeehilprss',
#  'acdeiimnost',
#  'aacdeilmnot',
#  'aacdeilnort',
#  'acdefiiinot',
#  'addegilmnny',
#  'deefiiinrst',
#  'adeeimnnost',
#  'adeinnoostt',
#  'deeiinrsstt',
#  'adeeiloprrz',
#  'adeenprssst',
#  'adeeilmnrst',
#  'cdeiinoprst',
#  'adeeimnnrtt',
#  'deeiimnnrst',
#  'adehhioppst',
#  'cdeeimnnrst',
#  'cdeinorsstu',
#  'cdeeiorrssv',
#  'adeehinrsst',
#  'deiinnossst',
#  'abdeilllssy',
#  'diiiimnossv',
#  'deflopprrsu',
#  'aeiilmnorst',
#  'bdeeeimorrr',
#  'eeilmnoosst',
#  'aeeimnnorst',
#  'aeeinnorstv',
#  'aeeilmnnstt',
#  'eeeinprrsst',
#  'adeeeinnrtt',
#  'aeeimnnortu',
#  'abeehilrsst',
#  'aceghilloot',
#  'eegilmoosty',
#  'aceiinosttx',
#  'abbdefiorrs',
#  'afiilnorstt',
#  'aeefhlopprs',
#  'adefloorstw',
#  'acfgiinnort',
#  'aefinooprst',
#  'adefnorrssw',
#  'aceeggimnot',
#  'acgimnoorst',
#  'aeeginnorst',
#  'acdeeginnrs',
#  'aaeeginprst',
#  'adeeegilmnr',
#  'eeghossstuu',
#  'eeginsssstu',
#  'aadeehmrsst',
#  'adeghinprss',
#  'abeghiinnrt',
#  'aaehiimnsst',
#  'chiiinorsst',
#  'eghhilosstu',
#  'eehhmoorstu',
#  'efhlnrsstuu',
#  'acehlnoprty',
#  'aeiilmmorst',
#  'aeeiimprstv',
#  'aeiiilmprst',
#  'aeeimnoprst',
#  'aeimnoprttu',
#  'iiimnoopsst',
#  'beeiilmprss',
#  'eiimnoprsss',
#  'giiimnnprst',
#  'aacdeiinttv',
#  'aaceiinsttv',
#  'aceinooprrt',
#  'deefiiinnst',
#  'acfiinnorst',
#  'aefiinnostt',
#  'aeiimnnorst',
#  'aegiinnortt',
#  'aeegiinrttv',
#  'aceiimnortt',
#  'ceeilnoprtu',
#  'deeehimnrst',
#  'eeehimnrsst',
#  'aeiilnnrtty',
#  'aeehinprsst',
#  'eeeinprrrtt',
#  'eegiinnnrtv',
#  'eeeiinrrtvw',
#  'eeeinnrsssv',
#  'deeiimnrrst',
#  'abdeekorrsy',
#  'aeiilnorstt',
#  'aehimprssst',
#  'aaimnorsttu',
#  'adeeiimrstx',
#  'acdeeiimnst',
#  'aeimnnorstu',
#  'aaceeillmns',
#  'aegiilmnrst',
#  'deeiimnorst',
#  'acghimnoopr',
#  'ceilmorstuu',
#  'aiilmnosttu',
#  'aceeinnortv',
#  'acgiinorsst',
#  'ehiooprsstt',
#  'acghimnortu',
#  'ddeinorsttu',
#  'aceinoorstv',
#  'eeikorrsstv',
#  'aceeeprsstt',
#  'aaeilmnprst',
#  'adeiinoprtt',
#  'aeiinoprrtt',
#  'aeeiprsstuz',
#  'aeenoprrstt',
#  'aeginnprstt',
#  'cdeekooprsw',
#  'aceilnopstu',
#  'aceeennprst',
#  'ceinoprsssu',
#  'aeeeginprrt',
#  'eeiioprsstt',
#  'aceeiipprtt',
#  'aceiilprstt',
#  'eeiinoprstt',
#  'aeghopprrty',
#  'eeghilnoops',
#  'acghiopprty',
#  'cefhilprstu',
#  'aeeilmnprst',
#  'aefllprsttu',
#  'aeilmoprrty',
#  'aaeinoprrst',
#  'cdeeeoprrss',
#  'eeillprsuvy',
#  'cdeeehlprsu',
#  'eeeinnprstt',
#  'abeinooprrt',
#  'eeoprrssstu',
#  'ceeoprrsstt',
#  'eiinooprrsv',
#  'acdeilnortu',
#  'aaeiilnortz',
#  'abceeeilrsv',
#  'ceeinnoorrt',
#  'aegiinnrstt',
#  'adeeiilrtvz',
#  'aeeiilrstvz',
#  'aceghinoprr',
#  'eeeioprrrst',
#  'eeeelnprsst',
#  'aefmnorrrst',
#  'eehloprrstu',
#  'eeiinrssstz',
#  'deeinorsssw',
#  'aciinorsttu',
#  'aeeilnsssst',
#  'acefhllsstu',
#  'eeehilrsstv',
#  'ceehiknssst',
#  'eiillooqssu',
#  'aeeiprssstt',
#  'abeiiilsstu',
#  'cehinnorssy',
#  'aceioprrstt',
#  'aceiilnrstu',
#  'defillorsww',
#  'abcdeorstu',
#  'aabceginrt',
#  'abinooprst',
#  'abersssttu',
#  'acceinorst',
#  'aceilnosst',
#  'aacgiinttv',
#  'aaciinottv',
#  'aaadeimnnt',
#  'adeiimnrst',
#  'adehimnors',
#  'adiimnnoot',
#  'adeinorsst',
#  'aadilnostu',
#  'aeegiloors',
#  'adeforrstw',
#  'aagillmnry',
#  'aghilmorst',
#  'aaeilnorst',
#  'aegilmnnst',
#  'aeeilmnnst',
#  'aaeeilrstt',
#  'aeegillors',
#  'aegillorst',
#  'aacillnoot',
#  'aceillorst',
#  'aaillnopst',
#  'aciilrsttu',
#  'aaehimrstu',
#  'aaeimnostz',
#  'agiimnorst',
#  'acehimoprt',
#  'aacegilnst',
#  'aagilnosst',
#  'aceeinrsst',
#  'acehinorst',
#  'adeillnosu',
#  'aaeghmnopr',
#  'aaginnostt',
#  'aceiinortt',
#  'aeehinprst',
#  'adeimnnort',
#  'aaiilmnnot',
#  'aeiimnnost',
#  'aaegilnptu',
#  'aadeinqttu',
#  'aeiinpssst',
#  'aceiinpstt',
#  'aeinrssstt',
#  'aadeinrstt',
#  'abemorrstu',
#  'acdefhinrs',
#  'acehiprrst',
#  'aeeginnrst',
#  'aeeginrstt',
#  'aaceinrsst',
#  'aacccioprs',
#  'aaeginprst',
#  'aeeiiprsst',
#  'adeelrssty',
#  'acciorstty',
#  'aeensssttu',
#  'aailnosstt',
#  'aiinorsttt',
#  'acgiinnotu',
#  'aacdelotuv',
#  'aaceiirstv',
#  'aabcdehkls',
#  'aabeiilnst',
#  'abdeelnors',
#  'abefllrrsu',
#  'abeeilnrss',
#  'abefklsstu',
#  'abekkorstw',
#  'aabdeirsst',
#  'abceghimnr',
#  'bdeggginru',
#  'beeillrstt',
#  'beeinrsstt',
#  'abcikllsst',
#  'abehoosstu',
#  'begilnorst',
#  'abeeirrsss',
#  'aaabekrswy',
#  'abddeiorss',
#  'aabdilorst',
#  'abdeilmors',
#  'bcefklstuu',
#  'acdehipsst',
#  'acceilnoss',
#  'aceelnrstu',
#  'aaccimnors',
#  'acdeinoort',
#  'aceginprst',
#  'accehirrst',
#  'acdeeilrst',
#  'acginnoort',
#  'aceeimrsss',
#  'acelossstu',
#  'aacdeglotu',
#  'aaceglostu',
#  'accehimsst',
#  'aceegiorst',
#  'acehinpsst',
#  'acdeeilnns',
#  'abceeelrst',
#  'cdeiillnos',
#  'aceeilmnst',
#  'aceeilnrst',
#  'ceinnorstu',
#  'aceeinrstt',
#  'ceefiirrst',
#  'cefgiinrty',
#  'cdeeirsttu',
#  'aceehlnnrs',
#  'aceghinprt',
#  'aceehrrrst',
#  'aceghinrrt',
#  'aceghinrtt',
#  'acehinsstt',
#  'cceeghiknr',
#  'acdhimorst',
#  'achimnorst',
#  'cehilorsty',
#  'ceeiinsstz',
#  'aceillnort',
#  'aceelrrstt',
#  'aceeilmsst',
#  'aceginnors',
#  'cceeginort',
#  'acginnoost',
#  'cgiinnoost',
#  'cdeefinorr',
#  'ceinorrssu',
#  'acgillnops',
#  'cdeemmnors',
#  'ceimooprtt',
#  'cddemnoopu',
#  'cdeemoprss',
#  'cceennorst',
#  'cceginnort',
#  'cceinnoort',
#  'cceeinortz',
#  'cefginorsu',
#  'ceenorrssv',
#  'ceginnorsv',
#  'cgiinnoprs',
#  'acinnorsst',
#  'aceinnorst',
#  'ceginnnott',
#  'aceennortv',
#  'acceelnosv',
#  'ceenorrstv',
#  'acdiilorty',
#  'acegilnort',
#  'ceeinossss',
#  'ciillnoost',
#  'acloorstuy',
#  'ceginnortu',
#  'acdeellorv',
#  'ceiloprssv',
#  'aceeiinnrt',
#  'aceeilrtvy',
#  'aceiirttvy',
#  'acdeeilnrt',
#  'aceimnorst',
#  'ccceeinrst',
#  'acgiilnrtu',
#  'acegilrstu',
#  'acchioptty',
#  'adeehilprs',
#  'acdegiimnt',
#  'acdeiimnot',
#  'acdeiilnos',
#  'cdeeilnnos',
#  'cdeemooprs',
#  'cddeinostu',
#  'ddeehnorsu',
#  'adefilnost',
#  'deeeflorrw',
#  'deeforrsst',
#  'deeeilrrsv',
#  'adeginnrtu',
#  'adeeimnnot',
#  'adeinnoott',
#  'adeeinottv',
#  'cdeennorsu',
#  'deiinnostt',
#  'ddeeiiorxz',
#  'deeilnopst',
#  'deiinoopst',
#  'adeinopttu',
#  'adeeimrstt',
#  'cdeioprrst',
#  'deeinnostt',
#  'deeeimnrst',
#  'deeeloprsv',
#  'deeeinsssw',
#  'abdiilosst',
#  'acdiinorty',
#  'dgiiinnost',
#  'deeiimnnrt',
#  'cdeiinorst',
#  'cdeeinrsst',
#  'acdgiinnst',
#  'cdeeinrrss',
#  'cdegiinnrs',
#  'cdeinorstu',
#  'cdeeiorrsv',
#  'cdeeilrsty',
#  'ddeeinorsw',
#  'dehiiinrst',
#  'adeiiprrss',
#  'deiinnosst',
#  'deiillrsst',
#  'cdeiinrstt',
#  'adeiinrrst',
#  'bdeiirsttu',
#  'acdeimnors',
#  'adgginnoor',
#  'aeehinrsst',
#  'aeehilrstt',
#  'aeghilnrst',
#  'aehmorrstw',
#  'aeeinrsstw',
#  'adeeoprssv',
#  'adeiilorst',
#  'aeeeglrsss',
#  'eeginorsss',
#  'aeelmorsst',
#  'aeeilrsttu',
#  'beeilmrstt',
#  'aeeilmnsst',
#  'aeeimnnort',
#  'acceinsstu',
#  'acegilnnps',
#  'ddeeimnors',
#  'ccdeinoops',
#  'degilnnruy',
#  'aeeginnrtv',
#  'aeeinnortv',
#  'deeeefnrtt',
#  'aadeglnnrs',
#  'aeggiilnnr',
#  'eeeginrrst',
#  'cdeeelnors',
#  'aeeinnrstt',
#  'eeeiinrstt',
#  'einnooprst',
#  'eeiloprsst',
#  'eeiiinqstu',
#  'ceiimorsst',
#  'ceeginoort',
#  'aeeinrrrst',
#  'acegilnops',
#  'accehiorst',
#  'aegiinsttv',
#  'aeiinosttv',
#  'eeghiloost',
#  'aeeioprstv',
#  'eeeilnsssv',
#  'aceiinottx',
#  'deeeiprstx',
#  'aefhinorss',
#  'ceeefnorrs',
#  'abbdefiorr',
#  'beffiillrs',
#  'abefgilrss',
#  'afiilnortt',
#  'efgiinprst',
#  'efimorrsst',
#  'effilnsstu',
#  'aeefhloppr',
#  'adefloortw',
#  'eeffginorr',
#  'aeefgorsst',
#  'acdefinort',
#  'aefinooprt',
#  'defginnoru',
#  'efgghiinrt',
#  'eeefhnrrss',
#  'deefiilnrs',
#  'eefimnrstu',
#  'adeeeggrst',
#  'adegiilnot',
#  'aeggimnnrt',
#  'aeginrrstu',
#  'aaeglrsttu',
#  'aeegginnrt',
#  'eeegimorst',
#  'aeegimnrst',
#  'adeeginrss',
#  'eghiorsttw',
#  'egilmnooss',
#  'acgilorsuy',
#  'aadginorst',
#  'aeghnoprry',
#  'aegilnrstu',
#  'adeeginrrs',
#  'adeeginnrs',
#  'deginnorst',
#  'egiinrsstt',
#  'deglnorssu',
#  'degginnoru',
#  'eeghosstuu',
#  'aginostttu',
#  'aachimnors',
#  'aceehhirst',
#  'aadeehmrst',
#  'adeghinprs',
#  'eehmopssty',
#  'aeghiinnrt',
#  'abdeehinrt',
#  'abeehinrst',
#  'ehiimprsst',
#  'eehmnoorsw',
#  'eeghimnoos',
#  'eehoprssst',
#  'aeehorssuw',
#  'ehkoorssuw',
#  'himnopssty',
#  'acdeiiilst',
#  'adeeiilrsz',
#  'aabceilmns',
#  'aciimnopst',
#  'aeilmnoprs',
#  'aeilmnprst',
#  'acimnoprty',
#  'eimnoprstu',
#  'aceeimprst',
#  'aeegimnprt',
#  'eiimnoprss',
#  'eeiimprssv',
#  'aaceiinttv',
#  'aciinnostu',
#  'ceiinnopst',
#  'ceeiinpstv',
#  'ceilnorssu',
#  'acgiinnost',
#  'cdeeiinrst',
#  'abeiinnrst',
#  'acfiinnort',
#  'abehiinrst',
#  'cceeinnnos',
#  'aceilnostu',
#  'aiinnorstu',
#  'aeillnrsst',
#  'eimnnrsttu',
#  'aceilnrsst',
#  'adeeginrrt',
#  'eeilnoprst',
#  'deeinoprst',
#  'deeeinnrtv',
#  'aceiiimnst',
#  'agiinnrstt',
#  'einnoorsst',
#  'adeeinrrst',
#  'aehilmorst',
#  'eiiooprsst',
#  'adeeijoprs',
#  'abdeekorry',
#  'aceelqrrsu',
#  'aeeelmnsss',
#  'aeeilnsssz',
#  'abeelmnrsu',
#  'eegilnrstt',
#  'eeghilnrst',
#  'egghiilnrt',
#  'eeilmnosst',
#  'eeilmnpsss',
#  'ehilnoopst',
#  'beilmooost',
#  'egiloopsty',
#  'degilnostu',
#  'aeiilmnrsu',
#  'eellrssstu',
#  'eegilnossy',
#  'adeeilmnrs',
#  'aaegimrstt',
#  'aeegimnsst',
#  'abeeilmrss',
#  'aelmnorsst',
#  'aeeimnrstt',
#  'aceeimrsst',
#  'aehimprsst',
#  'aeeimnssst',
#  'aaimnorttu',
#  'adeillmnos',
#  'aceiilmnst',
#  'eeimnnorst',
#  'eeimoorstz',
#  'aabeelmstt',
#  'deeimoorst',
#  'eemmnoorst',
#  'ceimooprrs',
#  'ceimmoorst',
#  'aeiiilmrst',
#  'eeiimnrsss',
#  'adegiilmns',
#  'adeeilmrst',
#  'cdeimnostu',
#  'efimnorstu',
#  'acehimmsst',
#  'aeeilmrsst',
#  'eiimnorsss',
#  'deeeimrsst',
#  'eimorrsttw',
#  'deeimnorsz',
#  'eeimnorsst',
#  'egiimnnost',
#  'aeiilmorst',
#  'acehimnors',
#  'eiimnoorst',
#  'aghmnooprs',
#  'egilmnooos',
#  'eilmnooops',
#  'eeemnssstu',
#  'agiilmnttu',
#  'ailmorsttu',
#  'ceeinoprss',
#  'aceeinnrst',
#  'aegiimnstv',
#  'aceilnopst',
#  'eghlnoopry',
#  'aeinnorstv',
#  'eehmnorstt',
#  'aiinnorstt',
#  'aeennopstt',
#  'aailnnopst',
#  'giinnnostu',
#  'adegnorssu',
#  'aaillnorty',
#  'aceiloosuv',
#  'eeiilnostv',
#  'acehlorrst',
#  'acgiimnors',
#  'aefilmmors',
#  'acdehmortu',
#  'agiknosttu',
#  'aceinoortv',
#  'bdeenorruv',
#  'adeeloprsv',
#  'eeeloprssv',
#  'eilloprssv',
#  'aeinorrstv',
#  'eeikorrstv',
#  'ehinoprssw',
#  'accfiiipst',
#  'aaacdiiprs',
#  'aaellnprty',
#  'aeiiprssst',
#  'acdeiiprst',
#  'adeinoprst',
#  'cdeekooprw',
#  'aceloprstu',
#  'adeeinprst',
#  'acdeeiprst',
#  'aceeennprt',
#  'abeeoprrst',
#  'ceeeiprrsv',
#  'ceeeipprtv',
#  'ceinoprssu',
#  'eemopprrty',
#  'efgimnoprr',
#  'eeimoprsst',
#  'aefmoprrst',
#  'eeimprrstt',
#  'aeefgilprs',
#  'eeinprsstt',
#  'egiinprsst',
#  'aenooprrst',
#  'aegiinnprt',
#  'eeiinoprtt',
#  'ceeikoprsw',
#  'aeginprsss',
#  'aeeinprsst',
#  'aaegiilprs',
#  'aeelprrsst',
#  'adeilpsttu',
#  'cefklopstu',
#  'eillnoopss',
#  'eeloprssty',
#  'deginnoprt',
#  'aeegoprrst',
#  'aiilnoopst',
#  'aeoprrsstt',
#  'aenoopssst',
#  'aaeinoprrt',
#  'eilnoprssu',
#  'eegillnprs',
#  'eeenprrsst',
#  'eeginprstt',
#  'cegiilnprs',
#  'aeginprstt',
#  'eiloprsuvy',
#  'cdeeoprrsu',
#  'defnooprru',
#  'aegmoprrrs',
#  'celnoprsuu',
#  'aeoprrsstu',
#  'ehioprssst',
#  'eginoprstt',
#  'eioprrssuv',
#  'eeinnpsssu',
#  'ainoprsstu',
#  'aaeinrrstw',
#  'aacdeehrtt',
#  'aceiilrstt',
#  'ddeginnoru',
#  'aeeggilnrt',
#  'aeginrrstt',
#  'eegginrrss',
#  'aegilnortu',
#  'aeeghinrrs',
#  'cddeeinrtu',
#  'adeeinrstt',
#  'egiiknnrtt',
#  'aeeiilrtvz',
#  'aabeeellrs',
#  'ceeinorsst',
#  'ceeginprst',
#  'eeghinrstt',
#  'aeeilrrstv',
#  'aceilrstuv',
#  'eehinnorst',
#  'aeghilnrss',
#  ...]

# %%
[anagrams_by_sig[sig] for sig in sorted(anagrams_by_sig.keys(), key=len, reverse=True)]
# Out:
# [{'microphotographies', 'photomicrographies'},
#  {'pathophysiological', 'physiopathological'},
#  {'autoradiographies', 'radioautographies'},
#  {'microphotographic', 'photomicrographic'},
#  {'pathophysiologies', 'physiopathologies'},
#  {'phototelegraphies', 'telephotographies'},
#  {'autoradiographic', 'radioautographic'},
#  {'chromatographers', 'rechromatographs'},
#  {'dessertspoonfuls', 'dessertspoonsful'},
#  {'impressibilities', 'permissibilities'},
#  {'impressivenesses', 'permissivenesses'},
#  {'microphotographs', 'photomicrographs'},
#  {'microphotography', 'photomicrography'},
#  {'pathophysiologic', 'physiopathologic'},
#  {'algorithmically', 'logarithmically'},
#  {'attentivenesses', 'tentativenesses'},
#  {'autoradiographs', 'radioautographs'},
#  {'autoradiography', 'radioautography'},
#  {'chromatographer', 'rechromatograph'},
#  {'electromagnetic', 'magnetoelectric'},
#  {'microphotograph', 'photomicrograph'},
#  {'pathophysiology', 'physiopathology'},
#  {'phototelegraphy', 'telephotography'},
#  {'statelessnesses', 'tastelessnesses'},
#  {'anticensorship', 'containerships'},
#  {'autoradiograph', 'radioautograph'},
#  {'certifications', 'rectifications'},
#  {'choreographers', 'rechoreographs'},
#  {'conservational', 'conversational'},
#  {'conservatoires', 'conservatories'},
#  {'consolidations', 'disconsolation'},
#  {'creativenesses', 'reactivenesses'},
#  {'demythologizer', 'remythologized'},
#  {'densitometries', 'endometritises'},
#  {'discreetnesses', 'discretenesses'},
#  {'discriminators', 'doctrinairisms'},
#  {'disintegration', 'disorientating'},
#  {'egocentrically', 'geocentrically'},
#  {'fictionalising', 'lignifications'},
#  {'impressibility', 'permissibility'},
#  {'impressionisms', 'misimpressions'},
#  {'impressiveness', 'permissiveness'},
#  {'indirectnesses', 'indiscreetness'},
#  {'interrogatives', 'tergiversation'},
#  {'paradisaically', 'paradisiacally'},
#  {'perviousnesses', 'previousnesses'},
#  {'precociousness', 'preconsciouses'},
#  {'propitiousness', 'superpositions'},
#  {'tablespoonfuls', 'tablespoonsful'},
#  {'accouterments', 'accoutrements'},
#  {'acetonitriles', 'intersocietal'},
#  {'adorabilities', 'roadabilities'},
#  {'antiparticles', 'paternalistic'},
#  {'antirecession', 'containerises'},
#  {'argentiferous', 'garnetiferous'},
#  {'attentiveness', 'tentativeness'},
#  {'boardsailings', 'sailboardings'},
#  {'brinkmanships', 'brinksmanship'},
#  {'caravansaries', 'caravanserais'},
#  {'cephalometric', 'petrochemical'},
#  {'certification', 'rectification'},
#  {'chlorinations', 'nonhistorical'},
#  {'choreographer', 'rechoreograph'},
#  {'coalitionists', 'solicitations'},
#  {'commercialist', 'microclimates'},
#  {'commissioners', 'recommissions'},
#  {'conservancies', 'conversancies'},
#  {'conservations', 'conversations'},
#  {'conservatoire', 'overreactions'},
#  {'containerised', 'inconsiderate'},
#  {'contrarieties', 'recreationist'},
#  {'counterdemand', 'countermanded'},
#  {'counterstains', 'encrustations'},
#  {'discriminator', 'doctrinairism'},
#  {'exploitations', 'sexploitation'},
#  {'forwardnesses', 'frowardnesses'},
#  {'haplessnesses', 'shapelessness'},
#  {'hurtfulnesses', 'ruthfulnesses'},
#  {'imperfections', 'perfectionism'},
#  {'impersonating', 'impregnations'},
#  {'impressionism', 'misimpression'},
#  {'inactivations', 'vaticinations'},
#  {'interactional', 'intercalation'},
#  {'interoceptors', 'retrospection'},
#  {'interspecific', 'prescientific'},
#  {'isoproterenol', 'poltrooneries'},
#  {'marginalities', 'materialising'},
#  {'nephrologists', 'phrenologists'},
#  {'overcautioned', 'overeducation'},
#  {'overissuances', 'veraciousness'},
#  {'personalistic', 'pictorialness'},
#  {'phenomenalist', 'phentolamines'},
#  {'photographers', 'rephotographs'},
#  {'reintegration', 'reorientating'},
#  {'relationships', 'rhinoplasties'},
#  {'restrengthens', 'strengtheners'},
#  {'ruinousnesses', 'unseriousness'},
#  {'statelessness', 'tastelessness'},
#  {'verifications', 'versification'},
#  {'accordionist', 'cardiotonics'},
#  {'accouterment', 'accoutrement'},
#  {'adulterating', 'triangulated'},
#  {'altercations', 'intercoastal'},
#  {'anacreontics', 'transoceanic'},
#  {'anecdotalism', 'declamations'},
#  {'antimosquito', 'misquotation'},
#  {'antinovelist', 'ventilations'},
#  {'arthroscopes', 'crapshooters'},
#  {'bacteriocins', 'brecciations'},
#  {'bardolatries', 'labradorites'},
#  {'behaviorisms', 'misbehaviors'},
#  {'boardsailing', 'sailboarding'},
#  {'broadcasters', 'rebroadcasts'},
#  {'chrismations', 'harmonicists'},
#  {'coalitionist', 'solicitation'},
#  {'colonialists', 'oscillations'},
#  {'commissioned', 'decommission'},
#  {'commissioner', 'recommission'},
#  {'concentering', 'reconnecting'},
#  {'concertizing', 'concretizing'},
#  {'conditioners', 'reconditions'},
#  {'conservation', 'conversation'},
#  {'consolidates', 'disconsolate'},
#  {'consumerists', 'misconstrues'},
#  {'cornerstones', 'nonsecretors'},
#  {'countermoved', 'overdocument'},
#  {'counterspies', 'persecutions'},
#  {'counterstain', 'encrustation'},
#  {'creationisms', 'miscreations', 'romanticises'},
#  {'creativeness', 'reactiveness'},
#  {'creativities', 'reactivities'},
#  {'crenelations', 'intolerances'},
#  {'customhouses', 'customshouse'},
#  {'deifications', 'edifications'},
#  {'densitometer', 'endometrites'},
#  {'depositional', 'despoliation'},
#  {'deprogrammer', 'reprogrammed'},
#  {'derivational', 'revalidation'},
#  {'desalination', 'nationalised'},
#  {'desensitizer', 'resensitized'},
#  {'despairingly', 'redisplaying'},
#  {'determinants', 'detrainments'},
#  {'detribalizes', 'restabilized'},
#  {'deuteranopic', 'precautioned'},
#  {'dilatoriness', 'disrelations'},
#  {'diphosphates', 'phosphatides'},
#  {'directnesses', 'discreetness', 'discreteness'},
#  {'discernments', 'rescindments'},
#  {'distemperate', 'premeditates'},
#  {'divisionisms', 'misdivisions'},
#  {'dominatrices', 'romanticised'},
#  {'earthinesses', 'heartinesses'},
#  {'earwitnesses', 'waterinesses'},
#  {'embroiderers', 'reembroiders'},
#  {'empathically', 'emphatically'},
#  {'entertaining', 'intenerating'},
#  {'enthusiastic', 'unchastities'},
#  {'enumerations', 'mountaineers'},
#  {'ethnocentric', 'technetronic'},
#  {'fiberglasses', 'fibreglasses'},
#  {'gastrulation', 'gratulations'},
#  {'greenkeepers', 'greenskeeper'},
#  {'hairbreadths', 'hairsbreadth'},
#  {'handbreadths', 'handsbreadth'},
#  {'housemothers', 'motherhouses'},
#  {'housepainter', 'neuropathies'},
#  {'immortalises', 'memorialists'},
#  {'impersonated', 'predominates'},
#  {'importancies', 'imprecations'},
#  {'impressively', 'permissively'},
#  {'inactivating', 'vaticinating'},
#  {'inactivation', 'vaticination'},
#  {'inconsistent', 'nonscientist'},
#  {'incorporates', 'procreations'},
#  {'indirections', 'indiscretion'},
#  {'indiscreetly', 'iridescently'},
#  {'infestations', 'sinfoniettas'},
#  {'inoculations', 'inosculation'},
#  {'inseminators', 'nitrosamines'},
#  {'intercessors', 'intercrosses'},
#  {'interpreters', 'reinterprets'},
#  {'interstation', 'strontianite'},
#  {'interviewers', 'reinterviews'},
#  {'lectionaries', 'neorealistic'},
#  {'multiservice', 'vermiculites'},
#  {'mythographer', 'thermography'},
#  {'narcolepsies', 'precessional'},
#  {'nephrologies', 'phrenologies', 'pigeonholers'},
#  {'nephrologist', 'phrenologist'},
#  {'nonelectives', 'nonselective'},
#  {'obscurantist', 'subtractions'},
#  {'paradisaical', 'paradisiacal'},
#  {'partitioners', 'repartitions'},
#  {'paternosters', 'transportees'},
#  {'penetrations', 'presentation'},
#  {'peripatetics', 'precipitates'},
#  {'perviousness', 'previousness'},
#  {'phenocrystic', 'pyrotechnics'},
#  {'philosophies', 'philosophise'},
#  {'photographer', 'rephotograph'},
#  {'phycologists', 'psychologist'},
#  {'postulancies', 'speculations'},
#  {'potentiators', 'protestation'},
#  {'pragmaticist', 'pragmatistic'},
#  {'predigestion', 'redepositing'},
#  {'preelections', 'preselection'},
#  {'probationers', 'reprobations'},
#  {'provisioners', 'reprovisions'},
#  {'psychologies', 'psychologise'},
#  {'rationalizes', 'realizations'},
#  {'reconnoiters', 'reconnoitres'},
#  {'redintegrate', 'reintegrated'},
#  {'relativizing', 'revitalizing'},
#  {'restrengthen', 'strengthener'},
#  {'retransforms', 'transformers'},
#  {'reupholsters', 'upholsterers'},
#  {'seismologist', 'semiologists'},
#  {'sensitometer', 'tensiometers'},
#  {'supersession', 'suspensories'},
#  {'synaesthesis', 'synesthesias'},
#  {'teaspoonfuls', 'teaspoonsful'},
#  {'viscometries', 'viscosimeter'},
#  {'aberrancies', 'carabineers'},
#  {'accessories', 'accessorise'},
#  {'acetanilids', 'dilatancies'},
#  {'acidimeters', 'mediatrices'},
#  {'activations', 'cavitations', 'vacationist'},
#  {'admonitions', 'dominations'},
#  {'adorability', 'roadability'},
#  {'adventurers', 'untraversed'},
#  {'aeronomists', 'astronomies'},
#  {'algorithmic', 'logarithmic'},
#  {'alienations', 'nationalise'},
#  {'alikenesses', 'leakinesses'},
#  {'allegorists', 'legislators'},
#  {'altitudinal', 'latitudinal'},
#  {'ancientries', 'creatinines', 'incinerates'},
#  {'anemographs', 'phanerogams'},
#  {'angrinesses', 'ranginesses'},
#  {'animadverts', 'maidservant'},
#  {'antagonists', 'stagnations'},
#  {'anthologies', 'theologians'},
#  {'antifascism', 'fanaticisms'},
#  {'antileprosy', 'personality'},
#  {'antimissile', 'laminitises'},
#  {'antimoderns', 'ordainments'},
#  {'antimonials', 'laminations', 'nationalism'},
#  {'antiphrasis', 'artisanship'},
#  {'antipyretic', 'pertinacity'},
#  {'antiquating', 'aquatinting'},
#  {'antiseptics', 'psittacines'},
#  {'arthrodesis', 'diarthroses'},
#  {'arthroscope', 'crapshooter', 'prothoraces'},
#  {'artillerist', 'triliterals'},
#  {'ascertained', 'deracinates'},
#  {'astrometric', 'meritocrats'},
#  {'attentively', 'tentatively'},
#  {'bacteriocin', 'brecciation'},
#  {'basketworks', 'workbaskets'},
#  {'behaviorism', 'misbehavior'},
#  {'bestialized', 'destabilize'},
#  {'blastopores', 'blastospore'},
#  {'breadthwise', 'whitebeards'},
#  {'broadcaster', 'rebroadcast'},
#  {'buccinators', 'obscurantic'},
#  {'calligraphy', 'graphically'},
#  {'capillarity', 'piratically'},
#  {'carotenoids', 'coordinates', 'decorations'},
#  {'carpentries', 'transpierce'},
#  {'cataloguing', 'coagulating'},
#  {'cattinesses', 'tacitnesses'},
#  {'centralised', 'credentials'},
#  {'centralises', 'linecasters'},
#  {'certifiable', 'rectifiable'},
#  {'chandeliers', 'chandleries'},
#  {'chrismation', 'harmonicist'},
#  {'chrysolites', 'chrysotiles'},
#  {'cimetidines', 'mendicities'},
#  {'coinferring', 'reinforcing'},
#  {'colonialist', 'oscillation'},
#  {'complicates', 'ectoplasmic'},
#  {'concentered', 'reconnected'},
#  {'concertinos', 'concretions'},
#  {'concertized', 'concretized'},
#  {'concertizes', 'concretizes'},
#  {'conditioned', 'decondition'},
#  {'conditioner', 'recondition'},
#  {'conservancy', 'conversancy'},
#  {'considerate', 'desecration'},
#  {'constancies', 'nonascetics'},
#  {'constructed', 'deconstruct'},
#  {'consumerist', 'misconstrue'},
#  {'contravenes', 'covenanters'},
#  {'cordierites', 'directories'},
#  {'corkinesses', 'rockinesses'},
#  {'cornerstone', 'nonsecretor'},
#  {'cosmetician', 'encomiastic'},
#  {'countervail', 'involucrate'},
#  {'creationism', 'miscreation', 'romanticise'},
#  {'creationist', 'recitations'},
#  {'crenelation', 'intolerance'},
#  {'crescendoed', 'decrescendo'},
#  {'cryptomeria', 'imprecatory'},
#  {'cushionless', 'slouchiness'},
#  {'darlingness', 'sanderlings'},
#  {'dealerships', 'leaderships'},
#  {'decimations', 'medications'},
#  {'declamation', 'nematocidal'},
#  {'declaration', 'redactional'},
#  {'deification', 'edification'},
#  {'demandingly', 'maddeningly'},
#  {'denitrifies', 'identifiers'},
#  {'denominates', 'emendations'},
#  {'denotations', 'detonations'},
#  {'dentistries', 'disinterest'},
#  {'depolarizer', 'repolarized'},
#  {'depressants', 'pantdresses'},
#  {'derailments', 'streamlined'},
#  {'description', 'predictions'},
#  {'determinant', 'detrainment'},
#  {'dinnertimes', 'intermedins'},
#  {'diphosphate', 'phosphatide'},
#  {'discernment', 'rescindment'},
#  {'discounters', 'rediscounts'},
#  {'discoverers', 'rediscovers'},
#  {'disheartens', 'threadiness'},
#  {'dissentions', 'distensions'},
#  {'dissyllable', 'disyllables'},
#  {'divisionism', 'misdivision'},
#  {'dropperfuls', 'droppersful'},
#  {'eliminators', 'normalities', 'orientalism'},
#  {'embroiderer', 'reembroider'},
#  {'emotionless', 'monostelies'},
#  {'enantiomers', 'renominates'},
#  {'enervations', 'venerations'},
#  {'entailments', 'sentimental'},
#  {'enterprises', 'intersperse'},
#  {'entertained', 'intenerated'},
#  {'enumeration', 'mountaineer'},
#  {'establisher', 'reestablish'},
#  {'ethological', 'theological'},
#  {'etymologies', 'etymologise'},
#  {'excitations', 'intoxicates'},
#  {'fiberboards', 'fibreboards'},
#  {'filtrations', 'flirtations'},
#  {'fleahoppers', 'leafhoppers'},
#  {'floodwaters', 'waterfloods'},
#  {'fornicating', 'fractioning'},
#  {'fortepianos', 'pianofortes'},
#  {'forwardness', 'frowardness'},
#  {'gametogenic', 'geomagnetic'},
#  {'gastronomic', 'monogastric'},
#  {'generations', 'nitrogenase'},
#  {'grandnieces', 'reascending'},
#  {'greasepaint', 'pageantries'},
#  {'greenmailed', 'legerdemain'},
#  {'guesthouses', 'houseguests'},
#  {'gustinesses', 'gutsinesses'},
#  {'headmasters', 'headstreams'},
#  {'headsprings', 'springheads'},
#  {'hibernating', 'inbreathing'},
#  {'histaminase', 'thiaminases'},
#  {'histrionics', 'trichinosis'},
#  {'houselights', 'lighthouses'},
#  {'housemother', 'motherhouse'},
#  {'hurtfulness', 'ruthfulness'},
#  {'hypocentral', 'lycanthrope'},
#  {'immortalise', 'memorialist'},
#  {'imperatives', 'semiprivate'},
#  {'imperialist', 'primalities'},
#  {'impersonate', 'permeations'},
#  {'importunate', 'permutation'},
#  {'impositions', 'misposition'},
#  {'impressible', 'permissible'},
#  {'impressions', 'permissions'},
#  {'imprintings', 'misprinting'},
#  {'inactivated', 'vaticinated'},
#  {'inactivates', 'vaticinates'},
#  {'incorporate', 'procreation'},
#  {'indefinites', 'intensified'},
#  {'infarctions', 'infractions'},
#  {'infestation', 'sinfonietta'},
#  {'inseminator', 'nitrosamine'},
#  {'integration', 'orientating'},
#  {'integrative', 'vinaigrette'},
#  {'interatomic', 'metrication'},
#  {'intercouple', 'neuroleptic'},
#  {'intermeshed', 'methedrines'},
#  {'intermeshes', 'smithereens'},
#  {'internality', 'itinerantly'},
#  {'interphases', 'parenthesis'},
#  {'interpreter', 'reinterpret'},
#  {'intervening', 'reinventing'},
#  {'interviewer', 'reinterview'},
#  {'invernesses', 'nervinesses'},
#  {'irredentism', 'misinterred'},
#  {'keyboarders', 'rekeyboards'},
#  {'literations', 'orientalist'},
#  {'masterships', 'shipmasters'},
#  {'maturations', 'natatoriums'},
#  {'mediatrixes', 'taxidermies'},
#  {'mendacities', 'nematicides'},
#  {'mensuration', 'numerations'},
#  {'mesalliance', 'miscellanea'},
#  {'misaltering', 'misrelating', 'trigeminals'},
#  {'misoriented', 'modernities'},
#  {'monographic', 'nomographic', 'phonogramic'},
#  {'multicourse', 'multisource'},
#  {'mutilations', 'stimulation'},
#  {'noncreative', 'nonreactive'},
#  {'organicists', 'ostracising'},
#  {'orthoepists', 'photoresist'},
#  {'outcharming', 'outmarching'},
#  {'outstridden', 'undistorted'},
#  {'overactions', 'revocations'},
#  {'overstrikes', 'strikeovers'},
#  {'pacesetters', 'streetscape'},
#  {'parliaments', 'paternalism'},
#  {'partitioned', 'trepidation'},
#  {'partitioner', 'repartition'},
#  {'pasteurizes', 'trapeziuses'},
#  {'paternoster', 'transportee'},
#  {'patternings', 'trapnesting'},
#  {'peckerwoods', 'woodpeckers'},
#  {'peculations', 'speculation'},
#  {'penetrances', 'repentances'},
#  {'percussions', 'supersonics'},
#  {'peregrinate', 'rerepeating'},
#  {'periostites', 'posterities'},
#  {'peripatetic', 'precipitate'},
#  {'peristaltic', 'triplicates'},
#  {'peritonites', 'petitioners', 'repetitions'},
#  {'petrography', 'typographer'},
#  {'phenologies', 'pigeonholes'},
#  {'pictography', 'typographic'},
#  {'pitcherfuls', 'pitchersful'},
#  {'planimeters', 'sempiternal'},
#  {'platterfuls', 'plattersful'},
#  {'polarimetry', 'temporarily'},
#  {'praetorians', 'reparations'},
#  {'predecessor', 'reprocessed'},
#  {'prelusively', 'repulsively'},
#  {'preschedule', 'sepulchered'},
#  {'presentient', 'spinnerette'},
#  {'probationer', 'reprobation'},
#  {'proestruses', 'superstores'},
#  {'protectress', 'retrospects'},
#  {'provisioner', 'reprovision'},
#  {'radiolucent', 'reductional'},
#  {'rationalize', 'realization'},
#  {'receivables', 'serviceable'},
#  {'reconnoiter', 'reconnoitre'},
#  {'reinstating', 'straitening'},
#  {'relativized', 'revitalized'},
#  {'relativizes', 'revitalizes'},
#  {'renographic', 'reproaching'},
#  {'repertoires', 'repertories'},
#  {'repleteness', 'terpeneless'},
#  {'retransform', 'transformer'},
#  {'reupholster', 'upholsterer'},
#  {'ritzinesses', 'sensitizers'},
#  {'rowdinesses', 'wordinesses'},
#  {'rustication', 'urtications'},
#  {'saltinesses', 'stainlesses'},
#  {'satchelfuls', 'satchelsful'},
#  {'shirtsleeve', 'theirselves'},
#  {'sketchiness', 'thicknesses'},
#  {'soliloquies', 'soliloquise'},
#  {'spessartite', 'stripteases'},
#  {'suabilities', 'usabilities'},
#  {'synchronies', 'synchronise'},
#  {'tetrasporic', 'triceratops'},
#  {'unclarities', 'unrealistic'},
#  {'wildflowers', 'wildfowlers'},
#  {'abductores', 'subcordate'},
#  {'abreacting', 'acerbating'},
#  {'absorption', 'probations'},
#  {'abstrusest', 'substrates'},
#  {'accretions', 'anorectics'},
#  {'actionless', 'coastlines', 'sectionals'},
#  {'activating', 'cavitating'},
#  {'activation', 'cavitation'},
#  {'adamantine', 'amantadine'},
#  {'administer', 'mistrained'},
#  {'admonisher', 'harmonised', 'rhodamines'},
#  {'admonition', 'domination'},
#  {'adroitness', 'intradoses'},
#  {'adulations', 'laudations'},
#  {'aerologies', 'areologies'},
#  {'afterwords', 'forwardest'},
#  {'alarmingly', 'marginally'},
#  {'algorithms', 'logarithms'},
#  {'alienators', 'rationales', 'senatorial'},
#  {'alignments', 'signalment'},
#  {'alinements', 'lineaments'},
#  {'aliterates', 'retaliates'},
#  {'allegories', 'allegorise'},
#  {'allegorist', 'legislator'},
#  {'allocation', 'locational'},
#  {'allosteric', 'sclerotial'},
#  {'altiplanos', 'spallation'},
#  {'altruistic', 'ultraistic'},
#  {'amateurish', 'hematurias'},
#  {'amazonites', 'anatomizes'},
#  {'amortising', 'migrations'},
#  {'amphoteric', 'metaphoric'},
#  {'analgetics', 'escalating'},
#  {'analogists', 'nostalgias'},
#  {'ancestries', 'resistance'},
#  {'anchorites', 'antechoirs'},
#  {'andouilles', 'delusional'},
#  {'anemograph', 'phanerogam'},
#  {'antagonist', 'stagnation'},
#  {'antierotic', 'recitation'},
#  {'antiherpes', 'interphase'},
#  {'antimodern', 'ordainment'},
#  {'antimonial', 'lamination'},
#  {'antimonies', 'antinomies'},
#  {'antiplague', 'plateauing'},
#  {'antiquated', 'aquatinted'},
#  {'antisepsis', 'inspissate'},
#  {'antiseptic', 'psittacine'},
#  {'antistress', 'resistants', 'straitness'},
#  {'antitrades', 'attainders'},
#  {'arboretums', 'tambourers'},
#  {'archfiends', 'franchised'},
#  {'archpriest', 'parritches'},
#  {'argentines', 'tangerines'},
#  {'argentites', 'estreating', 'integrates', 'interstage'},
#  {'ascertains', 'sectarians'},
#  {'ascocarpic', 'carpaccios'},
#  {'asperating', 'separating'},
#  {'asperities', 'patisserie'},
#  {'assertedly', 'steelyards'},
#  {'astrocytic', 'cryostatic'},
#  {'astuteness', 'tautnesses'},
#  {'atonalists', 'saltations'},
#  {'attritions', 'titrations'},
#  {'auctioning', 'cautioning'},
#  {'autoclaved', 'vacuolated'},
#  {'aviatrices', 'vicariates'},
#  {'backlashed', 'blackheads'},
#  {'banalities', 'insatiable'},
#  {'banderoles', 'bandoleers', 'endorsable'},
#  {'barrelfuls', 'barrelsful'},
#  {'baseliners', 'bleariness'},
#  {'basketfuls', 'basketsful'},
#  {'basketwork', 'workbasket'},
#  {'bastardies', 'bastardise'},
#  {'becharming', 'chambering'},
#  {'bedrugging', 'begrudging'},
#  {'belittlers', 'belletrist'},
#  {'bitterness', 'tenebrists'},
#  {'blacklists', 'stickballs'},
#  {'boathouses', 'houseboats'},
#  {'bolstering', 'lobstering'},
#  {'brasseries', 'brassieres'},
#  {'breakaways', 'breaksaway'},
#  {'broadsides', 'sideboards'},
#  {'broadtails', 'tailboards'},
#  {'bromeliads', 'mislabored'},
#  {'bucketfuls', 'bucketsful'},
#  {'cadetships', 'dispatches'},
#  {'calcinoses', 'neoclassic'},
#  {'calentures', 'unclearest'},
#  {'carcinomas', 'macaronics'},
#  {'carotenoid', 'coordinate', 'decoration'},
#  {'carpetings', 'precasting'},
#  {'carritches', 'scratchier'},
#  {'cartelised', 'decaliters'},
#  {'cartooning', 'coronating'},
#  {'cassimeres', 'smiercases'},
#  {'cassoulets', 'outclasses'},
#  {'catalogued', 'coagulated'},
#  {'catalogues', 'coagulates'},
#  {'catechisms', 'schematics'},
#  {'categories', 'categorise'},
#  {'cathepsins', 'patchiness'},
#  {'celandines', 'decennials'},
#  {'celebrates', 'resectable'},
#  {'celloidins', 'decillions'},
#  {'centesimal', 'lemniscate'},
#  {'centralise', 'interlaces', 'linecaster'},
#  {'centurions', 'continuers'},
#  {'certainest', 'intercaste'},
#  {'certifiers', 'rectifiers'},
#  {'certifying', 'rectifying'},
#  {'certitudes', 'rectitudes'},
#  {'channelers', 'rechannels'},
#  {'chaptering', 'repatching'},
#  {'charterers', 'recharters'},
#  {'chartering', 'recharting'},
#  {'chattering', 'ratcheting'},
#  {'chattiness', 'snatchiest'},
#  {'checkering', 'rechecking'},
#  {'chromatids', 'dichromats'},
#  {'chromatins', 'monarchist'},
#  {'chrysolite', 'chrysotile'},
#  {'citizeness', 'scientizes'},
#  {'citronella', 'interlocal'},
#  {'clatterers', 'craterlets'},
#  {'clematises', 'timescales'},
#  {'coarsening', 'ignorances'},
#  {'coerecting', 'egocentric', 'geocentric'},
#  {'cognations', 'contagions'},
#  {'cognitions', 'incognitos'},
#  {'coinferred', 'reinforced'},
#  {'coinsurers', 'recursions'},
#  {'collapsing', 'scalloping'},
#  {'commenders', 'recommends'},
#  {'competitor', 'optometric'},
#  {'compounded', 'decompound'},
#  {'compressed', 'decompress'},
#  {'concenters', 'connecters', 'reconnects'},
#  {'concerting', 'concreting'},
#  {'concertino', 'concretion'},
#  {'concertize', 'concretize'},
#  {'configures', 'refocusing'},
#  {'conservers', 'conversers'},
#  {'conserving', 'conversing'},
#  {'conspiring', 'incorpsing'},
#  {'constrains', 'transsonic'},
#  {'containers', 'crenations'},
#  {'contenting', 'contingent'},
#  {'contravene', 'covenanter'},
#  {'convalesce', 'covalences'},
#  {'converters', 'reconverts'},
#  {'cordiality', 'radiolytic'},
#  {'corelating', 'relocating'},
#  {'cosinesses', 'secessions'},
#  {'cotillions', 'octillions'},
#  {'cotylosaur', 'osculatory'},
#  {'countering', 'recounting'},
#  {'coveralled', 'overcalled'},
#  {'coverslips', 'slipcovers'},
#  {'creatinine', 'incinerate'},
#  {'creatively', 'reactively'},
#  {'creativity', 'reactivity'},
#  {'credential', 'interlaced'},
#  {'cremations', 'manticores'},
#  {'crescentic', 'eccentrics'},
#  {'curtailing', 'granulitic'},
#  {'curtilages', 'graticules'},
#  {'cytopathic', 'hypotactic'},
#  {'dealership', 'leadership'},
#  {'decimating', 'medicating'},
#  {'decimation', 'medication'},
#  {'decisional', 'lidocaines'},
#  {'declension', 'indolences'},
#  {'decomposer', 'recomposed'},
#  {'deductions', 'discounted'},
#  {'deerhounds', 'enshrouded'},
#  {'deflations', 'defoliants'},
#  {'deflowerer', 'reflowered'},
#  {'defrosters', 'fortressed'},
#  {'deliverers', 'redelivers', 'resilvered'},
#  {'denaturing', 'untreading'},
#  {'denominate', 'emendation'},
#  {'denotation', 'detonation'},
#  {'denotative', 'detonative'},
#  {'denouncers', 'uncensored'},
#  {'dentitions', 'distention', 'tendonitis'},
#  {'deoxidizer', 'reoxidized'},
#  {'depletions', 'diplotenes'},
#  {'deposition', 'positioned'},
#  {'deputation', 'outpainted'},
#  {'dermatites', 'mistreated'},
#  {'descriptor', 'predictors'},
#  {'detentions', 'tendonites'},
#  {'determines', 'misentered'},
#  {'developers', 'redevelops'},
#  {'dewinesses', 'widenesses'},
#  {'diabolists', 'idioblasts'},
#  {'dictionary', 'indicatory'},
#  {'digitonins', 'indigotins'},
#  {'dinnertime', 'intermedin'},
#  {'directions', 'discretion'},
#  {'directness', 'stridences'},
#  {'discanting', 'distancing'},
#  {'discerners', 'rescinders'},
#  {'discerning', 'rescinding'},
#  {'discounter', 'introduces', 'rediscount', 'reductions'},
#  {'discoverer', 'rediscover'},
#  {'discreetly', 'discretely'},
#  {'disendower', 'eiderdowns'},
#  {'disinherit', 'rhinitides'},
#  {'dispraiser', 'disrepairs'},
#  {'dissention', 'distension'},
#  {'distillers', 'redistills'},
#  {'distincter', 'interdicts'},
#  {'distrainer', 'irridentas'},
#  {'distribute', 'turbidites'},
#  {'dormancies', 'mordancies'},
#  {'dragooning', 'gadrooning'},
#  {'earthiness', 'heartiness'},
#  {'earthliest', 'stealthier'},
#  {'earthlings', 'slathering'},
#  {'earthworms', 'heartworms'},
#  {'earwitness', 'wateriness'},
#  {'eavesdrops', 'overpassed'},
#  {'editorials', 'idolatries'},
#  {'eelgrasses', 'greaseless'},
#  {'egressions', 'gorinesses'},
#  {'elastomers', 'salometers'},
#  {'elutriates', 'tutelaries'},
#  {'embrittles', 'trembliest'},
#  {'enamelists', 'mesnalties'},
#  {'enantiomer', 'renominate'},
#  {'encaustics', 'succinates'},
#  {'enclasping', 'spanceling'},
#  {'endodermis', 'modernised'},
#  {'endoscopic', 'picosecond'},
#  {'enduringly', 'underlying'},
#  {'enervating', 'venerating'},
#  {'enervation', 'veneration'},
#  {'enfettered', 'tenderfeet'},
#  {'engarlands', 'rangelands'},
#  {'engrailing', 'realigning'},
#  {'enregister', 'interreges'},
#  {'ensorceled', 'redolences'},
#  {'entertains', 'tenantries'},
#  {'entireties', 'eternities'},
#  {'entropions', 'prenotions'},
#  {'epistolers', 'pistoleers'},
#  {'equinities', 'inequities'},
#  {'eroticisms', 'isometrics'},
#  {'erotogenic', 'orogenetic'},
#  {'errantries', 'restrainer'},
#  {'escaloping', 'opalescing'},
#  {'escharotic', 'octarchies'},
#  {'estivating', 'negativist'},
#  {'estivation', 'novitiates'},
#  {'ethologies', 'theologies', 'theologise'},
#  {'evaporites', 'operatives'},
#  {'evilnesses', 'livenesses', 'vilenesses'},
#  {'excitation', 'intoxicate'},
#  {'expediters', 'preexisted'},
#  {'fashioners', 'refashions'},
#  {'ferrocenes', 'reenforces'},
#  {'fiberboard', 'fibreboard'},
#  {'fiberfills', 'fibrefills'},
#  {'fiberglass', 'fibreglass'},
#  {'filtration', 'flirtation'},
#  {'fingertips', 'presifting'},
#  {'firestorms', 'reformists'},
#  {'fitfulness', 'snuffliest'},
#  {'fleahopper', 'leafhopper'},
#  {'floodwater', 'waterflood'},
#  {'forefinger', 'reoffering'},
#  {'forestages', 'fosterages'},
#  {'fornicated', 'fractioned'},
#  {'fortepiano', 'pianoforte'},
#  {'foundering', 'refounding'},
#  {'freighting', 'refighting'},
#  {'fresheners', 'refreshens'},
#  {'friendlies', 'infielders'},
#  {'frumenties', 'furmenties'},
#  {'gadgeteers', 'segregated'},
#  {'gadolinite', 'intaglioed'},
#  {'garmenting', 'margenting'},
#  {'garnitures', 'treasuring'},
#  {'gastrulate', 'gratulates'},
#  {'generating', 'greatening'},
#  {'geometries', 'geometrise'},
#  {'germinates', 'steamering'},
#  {'gesneriads', 'reassigned'},
#  {'ghostwrite', 'growthiest'},
#  {'gloominess', 'neologisms'},
#  {'glycosuria', 'graciously'},
#  {'gradations', 'indagators'},
#  {'granophyre', 'renography'},
#  {'granulites', 'resaluting'},
#  {'grenadiers', 'rereadings'},
#  {'grenadines', 'serenading'},
#  {'grindstone', 'stringendo'},
#  {'grittiness', 'resittings', 'stringiest'},
#  {'groundless', 'groundsels'},
#  {'guerdoning', 'undergoing'},
#  {'guesthouse', 'houseguest'},
#  {'guttations', 'outstating'},
#  {'harmonicas', 'maraschino'},
#  {'hatcheries', 'thearchies'},
#  {'headmaster', 'headstream'},
#  {'headspring', 'springhead'},
#  {'hemoptyses', 'mesophytes'},
#  {'herniating', 'inearthing'},
#  {'hibernated', 'inbreathed'},
#  {'hibernates', 'inbreathes'},
#  {'hipsterism', 'shrimpiest'},
#  {'homeowners', 'horsewomen'},
#  {'homogenies', 'homogenise'},
#  {'hotpresses', 'prostheses'},
#  {'housewares', 'warehouses'},
#  {'houseworks', 'workhouses'},
#  {'hypnotisms', 'symphonist'},
#  {'idealistic', 'italicised'},
#  {'idealizers', 'serialized'},
#  {'imbalances', 'misbalance'},
#  {'impactions', 'miscaption'},
#  {'impersonal', 'prolamines'},
#  {'implanters', 'reimplants'},
#  {'importancy', 'patronymic'},
#  {'importunes', 'resumption'},
#  {'imprecates', 'spermaceti'},
#  {'impregnate', 'permeating'},
#  {'impression', 'permission'},
#  {'impressive', 'permissive'},
#  {'inactivate', 'vaticinate'},
#  {'incautions', 'insouciant'},
#  {'inceptions', 'inspection'},
#  {'inceptives', 'inspective'},
#  {'inclosures', 'reclusions'},
#  {'incognitas', 'sonicating'},
#  {'indiscreet', 'iridescent'},
#  {'inebriants', 'interbasin'},
#  {'infarction', 'infraction'},
#  {'inhabiters', 'reinhabits'},
#  {'innocences', 'nonscience'},
#  {'inoculates', 'inosculate'},
#  {'insinuator', 'ruinations', 'urinations'},
#  {'installers', 'reinstalls'},
#  {'instrument', 'nutriments'},
#  {'interclass', 'larcenists'},
#  {'intergrade', 'retreading'},
#  {'interlopes', 'repletions', 'terpineols'},
#  {'interposed', 'terpenoids'},
#  {'intervened', 'reinvented'},
#  {'intimacies', 'minacities'},
#  {'intrigants', 'transiting'},
#  {'ironstones', 'nonstories', 'serotonins'},
#  {'irredentas', 'restrained'},
#  {'isothermal', 'thimerosal'},
#  {'isotropies', 'porosities'},
#  {'jeopardies', 'jeopardise'},
#  {'keyboarder', 'rekeyboard'},
#  {'lacquerers', 'relacquers'},
#  {'lamenesses', 'malenesses'},
#  {'lazinesses', 'sleaziness'},
#  {'lebensraum', 'mensurable'},
#  {'letterings', 'resettling'},
#  {'lighteners', 'sheltering'},
#  {'lightering', 'relighting'},
#  {'limestones', 'milestones'},
#  {'limpnesses', 'simpleness'},
#  {'lithopones', 'phonolites'},
#  {'lobotomies', 'lobotomise'},
#  {'logotypies', 'typologies'},
#  {'longitudes', 'ungodliest'},
#  {'luminaires', 'luminaries'},
#  {'lusterless', 'resultless'},
#  {'lysogenies', 'lysogenise'},
#  {'madrilenes', 'mislearned'},
#  {'magistrate', 'sterigmata'},
#  {'magnesites', 'magnetises'},
#  {'marbleises', 'miserables'},
#  {'marlstones', 'mestranols'},
#  {'martensite', 'terminates'},
#  {'masseteric', 'miscreates'},
#  {'mastership', 'shipmaster'},
#  {'matinesses', 'steaminess'},
#  {'maturation', 'natatorium'},
#  {'medaillons', 'medallions'},
#  {'melanistic', 'militances'},
#  {'mentioners', 'minestrone'},
#  {'merozoites', 'zoometries'},
#  {'metastable', 'stablemate', 'tablemates'},
#  {'meteoroids', 'odometries'},
#  {'metronomes', 'monometers', 'monotremes'},
#  {'micropores', 'microspore'},
#  {'microtomes', 'osmometric'},
#  {'militaries', 'militarise'},
#  {'mirinesses', 'riminesses'},
#  {'misaligned', 'misdealing', 'misleading'},
#  {'misaltered', 'misrelated'},
#  {'miscounted', 'undomestic'},
#  {'misfortune', 'uniformest'},
#  {'mismatches', 'schematism'},
#  {'misrelates', 'semestrial'},
#  {'missioners', 'remissions'},
#  {'missteered', 'semidesert'},
#  {'miterworts', 'mitreworts'},
#  {'modernizes', 'sermonized'},
#  {'moisteners', 'remoistens'},
#  {'moistening', 'monetising'},
#  {'molarities', 'moralities'},
#  {'monarchies', 'nomarchies'},
#  {'monitories', 'moronities'},
#  {'monographs', 'nomographs', 'phonograms'},
#  {'monologies', 'nomologies'},
#  {'monopolies', 'monopolise'},
#  {'mutenesses', 'tenesmuses'},
#  {'mutilating', 'ultimating'},
#  {'mutilators', 'stimulator'},
#  {'necropsies', 'precession'},
#  {'nectarines', 'transience'},
#  {'negativism', 'timesaving'},
#  {'neoplastic', 'pleonastic'},
#  {'nephrology', 'phrenology'},
#  {'nervations', 'vernations'},
#  {'nethermost', 'stenotherm'},
#  {'nitrations', 'transition'},
#  {'nonseptate', 'panettones'},
#  {'nonspatial', 'planations'},
#  {'nonsuiting', 'outsinning'},
#  {'noseguards', 'sandgrouse'},
#  {'notarially', 'rationally'},
#  {'olivaceous', 'violaceous'},
#  {'olivenites', 'television'},
#  {'orchestral', 'trochlears'},
#  {'organicism', 'organismic'},
#  {'oriflammes', 'semiformal'},
#  {'outcharmed', 'outmarched'},
#  {'outskating', 'outtasking'},
#  {'overaction', 'revocation'},
#  {'overburden', 'overburned'},
#  {'overpedals', 'paloverdes'},
#  {'oversleeps', 'sleepovers'},
#  {'overspills', 'spillovers'},
#  {'overstrain', 'overtrains'},
#  {'overstrike', 'strikeover'},
#  {'ownerships', 'shipowners'},
#  {'pacificist', 'pacifistic'},
#  {'paradisaic', 'paradisiac'},
#  {'parentally', 'paternally', 'prenatally'},
#  {'patissiers', 'sparsities'},
#  {'patricides', 'pediatrics'},
#  {'patronised', 'predations'},
#  {'peckerwood', 'woodpecker'},
#  {'peculators', 'speculator'},
#  {'pedantries', 'pedestrian'},
#  {'pederastic', 'predicates'},
#  {'penetrance', 'repentance'},
#  {'perborates', 'reprobates'},
#  {'perceivers', 'preservice'},
#  {'perceptive', 'preceptive'},
#  {'percussion', 'supersonic'},
#  {'peremptory', 'preemptory'},
#  {'performing', 'preforming'},
#  {'peristomes', 'temporises'},
#  {'permafrost', 'preformats'},
#  {'permitters', 'pretermits'},
#  {'persiflage', 'pilferages'},
#  {'persistent', 'pinsetters', 'presentist', 'prettiness'},
#  {'persisting', 'springiest'},
#  {'personator', 'pronatores'},
#  {'pertaining', 'repainting'},
#  {'petitioner', 'repetition'},
#  {'pieceworks', 'workpieces'},
#  {'pingrasses', 'preassigns'},
#  {'pistareens', 'sparteines'},
#  {'plagiaries', 'plagiarise'},
#  {'plasterers', 'replasters'},
#  {'platitudes', 'stipulated'},
#  {'pocketfuls', 'pocketsful'},
#  {'pollenosis', 'pollinoses'},
#  {'polyesters', 'proselytes'},
#  {'portending', 'protending'},
#  {'porterages', 'prestorage', 'reportages'},
#  {'positional', 'spoliation'},
#  {'postarrest', 'prostrates'},
#  {'postseason', 'soapstones'},
#  {'praetorian', 'reparation'},
#  {'prelusions', 'repulsions'},
#  {'preselling', 'respelling'},
#  {'presenters', 'represents'},
#  {'presetting', 'pretesting'},
#  {'preslicing', 'resplicing'},
#  {'pretasting', 'spattering'},
#  {'previously', 'viperously'},
#  {'procedures', 'reproduces'},
#  {'profounder', 'underproof'},
#  {'programers', 'reprograms'},
#  {'pronucleus', 'uncouplers'},
#  {'prosateurs', 'pterosaurs'},
#  {'prosthesis', 'storeships'},
#  {'protesting', 'respotting'},
#  {'proviruses', 'supervisor'},
#  {'puninesses', 'supineness'},
#  {'rainspouts', 'supinators'},
#  {'rainwaters', 'warranties'},
#  {'reattached', 'tracheated'},
#  {'recitalist', 'triticales'},
#  {'redounding', 'underdoing'},
#  {'regelating', 'relegating'},
#  {'registrant', 'restarting'},
#  {'regressing', 'sniggerers'},
#  {'regulation', 'urogenital'},
#  {'rehearings', 'rehearsing'},
#  {'reinducted', 'uncredited', 'undirected'},
#  {'reinstated', 'straitened'},
#  {'reknitting', 'trinketing'},
#  {'relativize', 'revitalize'},
#  {'releasable', 'resealable'},
#  {'resections', 'secretions'},
#  {'respecting', 'sceptering'},
#  {'retightens', 'tighteners'},
#  {'retrievals', 'varletries'},
#  {'revictuals', 'victualers'},
#  {'rhinestone', 'threonines'},
#  {'ringhalses', 'shearlings'},
#  ...]

# %%
sorted(anagrams_by_sig.values(), key=len, reverse=True)
# Out:
# [{'apers',
#   'apres',
#   'asper',
#   'pares',
#   'parse',
#   'pears',
#   'prase',
#   'presa',
#   'rapes',
#   'reaps',
#   'spare',
#   'spear'},
#  {'alerts',
#   'alters',
#   'artels',
#   'estral',
#   'laster',
#   'ratels',
#   'salter',
#   'slater',
#   'staler',
#   'stelar',
#   'talers'},
#  {'least',
#   'setal',
#   'slate',
#   'stale',
#   'steal',
#   'stela',
#   'taels',
#   'tales',
#   'teals',
#   'tesla'},
#  {'anestri',
#   'antsier',
#   'nastier',
#   'ratines',
#   'retains',
#   'retinas',
#   'retsina',
#   'stainer',
#   'stearin'},
#  {'capers',
#   'crapes',
#   'escarp',
#   'pacers',
#   'parsec',
#   'recaps',
#   'scrape',
#   'secpar',
#   'spacer'},
#  {'estrin',
#   'inerts',
#   'insert',
#   'inters',
#   'niters',
#   'nitres',
#   'sinter',
#   'triens',
#   'trines'},
#  {'palest',
#   'palets',
#   'pastel',
#   'petals',
#   'plates',
#   'pleats',
#   'septal',
#   'staple',
#   'tepals'},
#  {'arles', 'earls', 'lares', 'laser', 'lears', 'rales', 'reals', 'seral'},
#  {'aspers',
#   'parses',
#   'passer',
#   'prases',
#   'repass',
#   'spares',
#   'sparse',
#   'spears'},
#  {'ates', 'east', 'eats', 'etas', 'sate', 'seat', 'seta', 'teas'},
#  {'carets',
#   'cartes',
#   'caster',
#   'caters',
#   'crates',
#   'reacts',
#   'recast',
#   'traces'},
#  {'earings',
#   'erasing',
#   'gainers',
#   'reagins',
#   'regains',
#   'reginas',
#   'searing',
#   'seringa'},
#  {'enters',
#   'nester',
#   'renest',
#   'rentes',
#   'resent',
#   'tenser',
#   'ternes',
#   'treens'},
#  {'lapse', 'leaps', 'pales', 'peals', 'pleas', 'salep', 'sepal', 'spale'},
#  {'peris', 'piers', 'pries', 'prise', 'ripes', 'speir', 'spier', 'spire'},
#  {'abets', 'baste', 'bates', 'beast', 'beats', 'betas', 'tabes'},
#  {'acres', 'cares', 'carse', 'escar', 'races', 'scare', 'serac'},
#  {'algins', 'aligns', 'lasing', 'liangs', 'ligans', 'lingas', 'signal'},
#  {'amens', 'manes', 'manse', 'means', 'mensa', 'names', 'nemas'},
#  {'angriest',
#   'astringe',
#   'ganister',
#   'gantries',
#   'granites',
#   'ingrates',
#   'rangiest'},
#  {'ardebs', 'bardes', 'beards', 'breads', 'debars', 'sabred', 'serdab'},
#  {'ares', 'arse', 'ears', 'eras', 'rase', 'sear', 'sera'},
#  {'aridest', 'astride', 'diaster', 'disrate', 'staider', 'tardies', 'tirades'},
#  {'aril', 'lair', 'lari', 'liar', 'lira', 'rail', 'rial'},
#  {'ariled', 'derail', 'dialer', 'laired', 'railed', 'redial', 'relaid'},
#  {'arils', 'lairs', 'laris', 'liars', 'liras', 'rails', 'rials'},
#  {'armets', 'master', 'maters', 'matres', 'ramets', 'stream', 'tamers'},
#  {'arrest', 'rarest', 'raster', 'raters', 'starer', 'tarres', 'terras'},
#  {'artiest', 'artiste', 'attires', 'iratest', 'ratites', 'striate', 'tastier'},
#  {'aspen', 'napes', 'neaps', 'panes', 'peans', 'sneap', 'spean'},
#  {'canter', 'carnet', 'centra', 'nectar', 'recant', 'tanrec', 'trance'},
#  {'canters', 'carnets', 'nectars', 'recants', 'scanter', 'tanrecs', 'trances'},
#  {'caret', 'carte', 'cater', 'crate', 'react', 'recta', 'trace'},
#  {'cruets', 'cruset', 'curets', 'eructs', 'rectus', 'recuts', 'truces'},
#  {'deist', 'diets', 'dites', 'edits', 'sited', 'stied', 'tides'},
#  {'drapes', 'padres', 'parsed', 'rasped', 'spader', 'spared', 'spread'},
#  {'elastin', 'entails', 'nailset', 'salient', 'saltine', 'slainte', 'tenails'},
#  {'emits', 'items', 'metis', 'mites', 'smite', 'stime', 'times'},
#  {'empires', 'emprise', 'epimers', 'imprese', 'premies', 'premise', 'spireme'},
#  {'enosis', 'eosins', 'essoin', 'noesis', 'noises', 'ossein', 'sonsie'},
#  {'esprits', 'persist', 'priests', 'spriest', 'sprites', 'stirpes', 'stripes'},
#  {'ester', 'reest', 'reset', 'steer', 'stere', 'terse', 'trees'},
#  {'estrous', 'oestrus', 'ousters', 'sourest', 'souters', 'stoures', 'tussore'},
#  {'lavers', 'ravels', 'salver', 'serval', 'slaver', 'velars', 'versal'},
#  {'laves', 'salve', 'selva', 'slave', 'vales', 'valse', 'veals'},
#  {'leapt', 'lepta', 'palet', 'petal', 'plate', 'pleat', 'tepal'},
#  {'merits', 'mister', 'miters', 'mitres', 'remits', 'smiter', 'timers'},
#  {'nestor', 'noters', 'stoner', 'tenors', 'tensor', 'toners', 'trones'},
#  {'paste', 'pates', 'peats', 'septa', 'spate', 'tapes', 'tepas'},
#  {'pinots', 'pintos', 'piston', 'pitons', 'points', 'postin', 'spinto'},
#  {'poster', 'presto', 'repots', 'respot', 'stoper', 'topers', 'tropes'},
#  {'resaw', 'sawer', 'sewar', 'sware', 'swear', 'wares', 'wears'},
#  {'acred', 'arced', 'cadre', 'cared', 'cedar', 'raced'},
#  {'aiders', 'deairs', 'irades', 'raised', 'redias', 'resaid'},
#  {'airts', 'astir', 'sitar', 'stair', 'stria', 'tarsi'},
#  {'albites', 'astilbe', 'bastile', 'bestial', 'blastie', 'stabile'},
#  {'alert', 'alter', 'artel', 'later', 'ratel', 'taler'},
#  {'alerting', 'altering', 'integral', 'relating', 'tanglier', 'triangle'},
#  {'alevin', 'alvine', 'valine', 'veinal', 'venial', 'vineal'},
#  {'aliens', 'alines', 'elains', 'lianes', 'saline', 'silane'},
#  {'aligners', 'engrails', 'nargiles', 'realigns', 'signaler', 'slangier'},
#  {'ardeb', 'barde', 'bared', 'beard', 'bread', 'debar'},
#  {'aretes', 'easter', 'eaters', 'reseat', 'seater', 'teaser'},
#  {'ashed', 'deash', 'hades', 'heads', 'sadhe', 'shade'},
#  {'aspirer', 'parries', 'praiser', 'rapiers', 'raspier', 'repairs'},
#  {'bares', 'baser', 'bears', 'braes', 'saber', 'sabre'},
#  {'bluest', 'bluets', 'bustle', 'butles', 'sublet', 'subtle'},
#  {'caress', 'carses', 'crases', 'escars', 'scares', 'seracs'},
#  {'carpels', 'clasper', 'parcels', 'placers', 'reclasp', 'scalper'},
#  {'claroes', 'coalers', 'escolar', 'oracles', 'recoals', 'solacer'},
#  {'corset', 'coster', 'escort', 'rectos', 'scoter', 'sector'},
#  {'cruet', 'curet', 'cuter', 'eruct', 'recut', 'truce'},
#  {'dater', 'derat', 'rated', 'tared', 'trade', 'tread'},
#  {'dearths', 'hardest', 'hardset', 'hatreds', 'threads', 'trashed'},
#  {'deers', 'drees', 'redes', 'reeds', 'seder', 'sered'},
#  {'deils', 'delis', 'idles', 'isled', 'sidle', 'slide'},
#  {'deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled'},
#  {'deposit', 'dopiest', 'podites', 'posited', 'sopited', 'topside'},
#  {'diols', 'idols', 'lidos', 'sloid', 'soldi', 'solid'},
#  {'diopters', 'dioptres', 'peridots', 'proteids', 'riposted', 'topsider'},
#  {'easters', 'reseats', 'searest', 'seaters', 'teasers', 'tessera'},
#  {'easting', 'eatings', 'ingates', 'ingesta', 'seating', 'teasing'},
#  {'elints', 'enlist', 'inlets', 'listen', 'silent', 'tinsel'},
#  {'esprit', 'priest', 'ripest', 'sprite', 'stripe', 'tripes'},
#  {'esters', 'reests', 'resets', 'serest', 'steers', 'steres'},
#  {'estrange', 'grantees', 'greatens', 'negaters', 'reagents', 'sergeant'},
#  {'eviler', 'levier', 'liever', 'relive', 'revile', 'veiler'},
#  {'gapers', 'gasper', 'grapes', 'pagers', 'parges', 'sparge'},
#  {'gaster', 'grates', 'greats', 'retags', 'stager', 'targes'},
#  {'girons', 'grison', 'groins', 'rosing', 'signor', 'soring'},
#  {'hales', 'heals', 'leash', 'selah', 'shale', 'sheal'},
#  {'hassel', 'hassle', 'lashes', 'selahs', 'shales', 'sheals'},
#  {'hectors', 'rochets', 'rotches', 'tochers', 'torches', 'troches'},
#  {'inset', 'neist', 'nites', 'senti', 'stein', 'tines'},
#  {'larees', 'leaser', 'reales', 'resale', 'reseal', 'sealer'},
#  {'leasts', 'slates', 'stales', 'steals', 'tassel', 'teslas'},
#  {'leets', 'sleet', 'steel', 'stele', 'teels', 'teles'},
#  {'luster', 'lustre', 'result', 'rustle', 'sutler', 'ulster'},
#  {'lusters', 'lustres', 'results', 'rustles', 'sutlers', 'ulsters'},
#  {'mates', 'meats', 'satem', 'steam', 'tames', 'teams'},
#  {'notes', 'onset', 'seton', 'steno', 'stone', 'tones'},
#  {'opts', 'post', 'pots', 'spot', 'stop', 'tops'},
#  {'painters', 'pantries', 'pertains', 'pinaster', 'pristane', 'repaints'},
#  {'palters', 'persalt', 'plaster', 'platers', 'psalter', 'stapler'},
#  {'parties', 'pastier', 'piaster', 'piastre', 'pirates', 'traipse'},
#  {'parts', 'prats', 'sprat', 'strap', 'tarps', 'traps'},
#  {'paster', 'paters', 'prates', 'repast', 'tapers', 'trapes'},
#  {'peers', 'perse', 'prees', 'prese', 'speer', 'spree'},
#  {'petrous', 'posture', 'pouters', 'proteus', 'spouter', 'troupes'},
#  {'piles', 'plies', 'slipe', 'speil', 'spiel', 'spile'},
#  {'pores', 'poser', 'prose', 'repos', 'ropes', 'spore'},
#  {'realist', 'retails', 'saltier', 'saltire', 'slatier', 'tailers'},
#  {'recepts', 'respect', 'scepter', 'sceptre', 'specter', 'spectre'},
#  {'reigns', 'renigs', 'resign', 'sering', 'signer', 'singer'},
#  {'reins', 'resin', 'rinse', 'risen', 'serin', 'siren'},
#  {'riots', 'rotis', 'tiros', 'torsi', 'trios', 'trois'},
#  {'rosets', 'sorest', 'stores', 'torses', 'tosser', 'tsores'},
#  {'staw', 'swat', 'taws', 'twas', 'wast', 'wats'},
#  {'stow', 'swot', 'tows', 'twos', 'wost', 'wots'},
#  {'abiders', 'braised', 'darbies', 'seabird', 'sidebar'},
#  {'actinons', 'canonist', 'contains', 'sanction', 'sonantic'},
#  {'actors', 'castor', 'costar', 'scrota', 'tarocs'},
#  {'admen', 'amend', 'maned', 'menad', 'named'},
#  {'agers', 'gears', 'rages', 'sager', 'sarge'},
#  {'aggers', 'eggars', 'gagers', 'sagger', 'seggar'},
#  {'aginner', 'earning', 'engrain', 'grannie', 'nearing'},
#  {'agrees', 'eagers', 'eagres', 'grease', 'ragees'},
#  {'aider', 'aired', 'deair', 'irade', 'redia'},
#  {'aidmen', 'daimen', 'maiden', 'median', 'medina'},
#  {'aigrets', 'gaiters', 'seagirt', 'stagier', 'triages'},
#  {'ailments', 'aliments', 'manliest', 'melanist', 'smaltine'},
#  {'airless', 'resails', 'sailers', 'serails', 'serials'},
#  {'airns', 'naris', 'rains', 'ranis', 'sarin'},
#  {'aisled', 'deasil', 'ideals', 'ladies', 'sailed'},
#  {'albas', 'baals', 'balas', 'balsa', 'basal'},
#  {'ales', 'lase', 'leas', 'sale', 'seal'},
#  {'algin', 'align', 'liang', 'ligan', 'linga'},
#  {'alien', 'aline', 'anile', 'elain', 'liane'},
#  {'aligner', 'engrail', 'nargile', 'realign', 'reginal'},
#  {'aliner', 'larine', 'linear', 'nailer', 'renail'},
#  {'alipeds', 'elapids', 'lapides', 'palsied', 'pleiads'},
#  {'alps', 'laps', 'pals', 'salp', 'slap'},
#  {'altars', 'astral', 'ratals', 'talars', 'tarsal'},
#  {'alts', 'last', 'lats', 'salt', 'slat'},
#  {'ambled', 'bedlam', 'beldam', 'blamed', 'lambed'},
#  {'ambler', 'blamer', 'lamber', 'marble', 'ramble'},
#  {'amblers', 'blamers', 'lambers', 'marbles', 'rambles'},
#  {'amen', 'mane', 'mean', 'name', 'nema'},
#  {'amines', 'animes', 'inseam', 'mesian', 'semina'},
#  {'angered', 'derange', 'enraged', 'grandee', 'grenade'},
#  {'angrier', 'earring', 'grainer', 'rangier', 'rearing'},
#  {'antes', 'etnas', 'nates', 'neats', 'stane'},
#  {'antis', 'saint', 'satin', 'stain', 'tains'},
#  {'antsiest', 'instates', 'nastiest', 'satinets', 'titaness'},
#  {'aper', 'pare', 'pear', 'rape', 'reap'},
#  {'apes', 'apse', 'pase', 'peas', 'spae'},
#  {'apter', 'pater', 'peart', 'prate', 'taper'},
#  {'arches', 'chares', 'chaser', 'eschar', 'search'},
#  {'arcuses', 'causers', 'cesuras', 'saucers', 'sucrase'},
#  {'arenites', 'arsenite', 'resinate', 'stearine', 'trainees'},
#  {'argle', 'glare', 'lager', 'large', 'regal'},
#  {'argons', 'groans', 'orangs', 'organs', 'sarong'},
#  {'ariels', 'resail', 'sailer', 'serail', 'serial'},
#  {'ariettes', 'iterates', 'teariest', 'treaties', 'treatise'},
#  {'arpent', 'enrapt', 'entrap', 'parent', 'trepan'},
#  {'arpents', 'entraps', 'parents', 'pastern', 'trepans'},
#  {'arts', 'rats', 'star', 'tars', 'tsar'},
#  {'ascot', 'coast', 'coats', 'costa', 'tacos'},
#  {'aspires', 'paresis', 'parises', 'praises', 'spireas'},
#  {'assertor', 'assorter', 'oratress', 'reassort', 'roasters'},
#  {'asset', 'easts', 'sates', 'seats', 'tasse'},
#  {'aster', 'rates', 'stare', 'tares', 'tears'},
#  {'ate', 'eat', 'eta', 'tae', 'tea'},
#  {'attunes', 'nutates', 'tautens', 'tetanus', 'unstate'},
#  {'awns', 'sawn', 'snaw', 'swan', 'wans'},
#  {'bestir', 'bister', 'bistre', 'biters', 'tribes'},
#  {'boaster', 'boaters', 'borates', 'rebatos', 'sorbate'},
#  {'bromes', 'ombers', 'ombres', 'somber', 'sombre'},
#  {'brutes', 'burets', 'buster', 'rebuts', 'tubers'},
#  {'caners', 'casern', 'cranes', 'nacres', 'rances'},
#  {'canister', 'ceratins', 'cisterna', 'creatins', 'scantier'},
#  {'carles', 'clears', 'lacers', 'scaler', 'sclera'},
#  {'centiares', 'cisternae', 'creatines', 'iterances', 'nectaries'},
#  {'cereus', 'ceruse', 'recuse', 'rescue', 'secure'},
#  {'certes', 'erects', 'resect', 'secret', 'terces'},
#  {'chaste', 'cheats', 'sachet', 'scathe', 'taches'},
#  {'cheater', 'hectare', 'recheat', 'reteach', 'teacher'},
#  {'cions', 'coins', 'icons', 'scion', 'sonic'},
#  {'corsets', 'costers', 'escorts', 'scoters', 'sectors'},
#  {'craals', 'lascar', 'rascal', 'sacral', 'scalar'},
#  {'cruse', 'cures', 'curse', 'ecrus', 'sucre'},
#  {'dales', 'deals', 'lades', 'lased', 'leads'},
#  {'daters', 'derats', 'stared', 'trades', 'treads'},
#  {'dates', 'sated', 'stade', 'stead', 'tsade'},
#  {'dearer', 'reader', 'reared', 'redear', 'reread'},
#  {'deer', 'dere', 'dree', 'rede', 'reed'},
#  {'deigns', 'design', 'dinges', 'signed', 'singed'},
#  {'deil', 'deli', 'diel', 'idle', 'lied'},
#  {'delist', 'idlest', 'listed', 'silted', 'tildes'},
#  {'demerit', 'dimeter', 'merited', 'mitered', 'retimed'},
#  {'demireps', 'epiderms', 'impeders', 'premised', 'simpered'},
#  {'derries', 'desirer', 'redries', 'resider', 'serried'},
#  {'designer', 'energids', 'redesign', 'reedings', 'resigned'},
#  {'destain', 'detains', 'instead', 'sainted', 'stained'},
#  {'diesel', 'ediles', 'elides', 'sedile', 'seidel'},
#  {'diet', 'dite', 'edit', 'tide', 'tied'},
#  {'dineros', 'indorse', 'ordines', 'rosined', 'sordine'},
#  {'dinger', 'engird', 'girned', 'reding', 'ringed'},
#  {'doers', 'doser', 'redos', 'resod', 'rosed'},
#  {'drawer', 'redraw', 'reward', 'warder', 'warred'},
#  {'drones', 'redons', 'snored', 'sonder', 'sorned'},
#  {'drupes', 'dupers', 'perdus', 'prudes', 'pursed'},
#  {'duels', 'dulse', 'leuds', 'ludes', 'slued'},
#  {'eaglets', 'gelates', 'legates', 'segetal', 'telegas'},
#  {'earing', 'gainer', 'reagin', 'regain', 'regina'},
#  {'earless', 'leasers', 'resales', 'reseals', 'sealers'},
#  {'earns', 'nares', 'nears', 'saner', 'snare'},
#  {'eath', 'haet', 'hate', 'heat', 'thae'},
#  {'editors', 'sortied', 'steroid', 'storied', 'triodes'},
#  {'elaters', 'realest', 'relates', 'reslate', 'stealer'},
#  {'entasis', 'nasties', 'sestina', 'tansies', 'tisanes'},
#  {'entrails', 'latrines', 'ratlines', 'retinals', 'trenails'},
#  {'enviers', 'inverse', 'veiners', 'venires', 'versine'},
#  {'eons', 'noes', 'nose', 'ones', 'sone'},
#  {'eroding', 'groined', 'ignored', 'negroid', 'redoing'},
#  {'eros', 'ores', 'roes', 'rose', 'sore'},
#  {'erugos', 'grouse', 'rogues', 'rouges', 'rugose'},
#  {'ervils', 'livers', 'livres', 'silver', 'sliver'},
#  {'escarps', 'parsecs', 'scrapes', 'secpars', 'spacers'},
#  {'estop', 'pesto', 'poets', 'stope', 'topes'},
#  {'estops', 'pestos', 'posset', 'ptoses', 'stopes'},
#  {'everts', 'revest', 'revets', 'verset', 'verste'},
#  {'fetors', 'forest', 'fortes', 'foster', 'softer'},
#  {'filets', 'fliest', 'flites', 'itself', 'stifle'},
#  {'fires', 'fries', 'frise', 'reifs', 'serif'},
#  {'gilder', 'girdle', 'glider', 'regild', 'ridgel'},
#  {'gilders', 'girdles', 'gliders', 'regilds', 'ridgels'},
#  {'granite', 'gratine', 'ingrate', 'tangier', 'tearing'},
#  {'grate', 'great', 'retag', 'targe', 'terga'},
#  {'halters', 'harslet', 'lathers', 'slather', 'thalers'},
#  {'hares', 'hears', 'rheas', 'share', 'shear'},
#  {'hector', 'rochet', 'rotche', 'tocher', 'troche'},
#  {'heros', 'hoers', 'horse', 'shoer', 'shore'},
#  {'hist', 'hits', 'shit', 'sith', 'this'},
#  {'hooters', 'reshoot', 'sheroot', 'shooter', 'soother'},
#  {'host', 'hots', 'shot', 'soth', 'tosh'},
#  {'inert', 'inter', 'niter', 'nitre', 'trine'},
#  {'inserted', 'nerdiest', 'resident', 'sintered', 'trendies'},
#  {'inserter', 'reinsert', 'reinters', 'rentiers', 'terrines'},
#  {'insure', 'inures', 'rusine', 'urines', 'ursine'},
#  {'intreat', 'iterant', 'nattier', 'nitrate', 'tertian'},
#  {'irons', 'noirs', 'noris', 'ornis', 'rosin'},
#  {'karns', 'knars', 'narks', 'ranks', 'snark'},
#  {'lameness', 'maleness', 'maneless', 'nameless', 'salesmen'},
#  {'lapses', 'passel', 'saleps', 'sepals', 'spales'},
#  {'late', 'tael', 'tale', 'teal', 'tela'},
#  {'latrine', 'ratline', 'reliant', 'retinal', 'trenail'},
#  {'lave', 'leva', 'vale', 'veal', 'vela'},
#  {'laveers', 'leavers', 'reveals', 'several', 'vealers'},
#  {'leapers', 'pleaser', 'presale', 'relapse', 'repeals'},
#  {'leviers', 'relives', 'reviles', 'servile', 'veilers'},
#  {'list', 'lits', 'silt', 'slit', 'tils'},
#  {'lister', 'liters', 'litres', 'relist', 'tilers'},
#  {'loops', 'polos', 'pools', 'sloop', 'spool'},
#  {'loots', 'lotos', 'sotol', 'stool', 'tools'},
#  {'lopers', 'polers', 'proles', 'sloper', 'splore'},
#  {'lores', 'loser', 'orles', 'roles', 'sorel'},
#  {'manos', 'mason', 'moans', 'monas', 'nomas'},
#  {'mares', 'marse', 'maser', 'reams', 'smear'},
#  {'mate', 'meat', 'meta', 'tame', 'team'},
#  {'merit', 'miter', 'mitre', 'remit', 'timer'},
#  {'nows', 'owns', 'snow', 'sown', 'wons'},
#  {'orthoses', 'reshoots', 'sheroots', 'shooters', 'soothers'},
#  {'ouster', 'outers', 'routes', 'souter', 'stoure'},
#  {'parers', 'parser', 'rapers', 'rasper', 'sparer'},
#  {'parleys', 'parsley', 'players', 'replays', 'sparely'},
#  {'part', 'prat', 'rapt', 'tarp', 'trap'},
#  {'partlets', 'platters', 'prattles', 'splatter', 'sprattle'},
#  {'pastries', 'piasters', 'piastres', 'raspiest', 'traipses'},
#  {'peins', 'penis', 'pines', 'snipe', 'spine'},
#  {'phrase', 'raphes', 'seraph', 'shaper', 'sherpa'},
#  {'pisser', 'prises', 'speirs', 'spiers', 'spires'},
#  {'plisse', 'slipes', 'speils', 'spiels', 'spiles'},
#  {'porters', 'presort', 'pretors', 'reports', 'sporter'},
#  {'prides', 'prised', 'redips', 'spider', 'spired'},
#  {'prosiest', 'prosties', 'reposits', 'ripostes', 'triposes'},
#  {'rackets', 'restack', 'retacks', 'stacker', 'tackers'},
#  {'ratos', 'roast', 'rotas', 'taros', 'toras'},
#  {'recused', 'reduces', 'rescued', 'secured', 'seducer'},
#  {'refits', 'resift', 'rifest', 'sifter', 'strife'},
#  {'resaws', 'sawers', 'sewars', 'swears', 'wrasse'},
#  {'resow', 'serow', 'sower', 'swore', 'worse'},
#  {'respects', 'scepters', 'sceptres', 'specters', 'spectres'},
#  {'restrain', 'retrains', 'strainer', 'terrains', 'trainers'},
#  {'retests', 'setters', 'streets', 'tersest', 'testers'},
#  {'riot', 'roti', 'tiro', 'tori', 'trio'},
#  {'roost', 'roots', 'rotos', 'toros', 'torso'},
#  {'roset', 'rotes', 'store', 'tores', 'torse'},
#  {'rosiest', 'sorites', 'sorties', 'stories', 'trioses'},
#  {'roust', 'routs', 'stour', 'torus', 'tours'},
#  {'rowth', 'throw', 'whort', 'worth', 'wroth'},
#  {'rues', 'ruse', 'suer', 'sure', 'user'},
#  {'ryots', 'story', 'stroy', 'troys', 'tyros'},
#  {'skate', 'stake', 'steak', 'takes', 'teaks'},
#  {'spirt', 'sprit', 'stirp', 'strip', 'trips'},
#  {'state', 'taste', 'tates', 'teats', 'testa'},
#  {'stater', 'taster', 'taters', 'tetras', 'treats'},
#  {'abet', 'bate', 'beat', 'beta'},
#  {'abler', 'baler', 'blare', 'blear'},
#  {'ables', 'bales', 'blase', 'sable'},
#  {'ablest', 'bleats', 'stable', 'tables'},
#  {'abreacts', 'bearcats', 'cabarets', 'cabresta'},
#  {'abuts', 'tabus', 'tsuba', 'tubas'},
#  {'acids', 'asdic', 'cadis', 'caids'},
#  {'acinar', 'arnica', 'carina', 'crania'},
#  {'acts', 'cast', 'cats', 'scat'},
#  {'adder', 'dared', 'dread', 'readd'},
#  {'adders', 'dreads', 'readds', 'sadder'},
#  {'adepter', 'predate', 'retaped', 'tapered'},
#  {'adheres', 'headers', 'hearsed', 'sheared'},
#  {'adits', 'ditas', 'staid', 'tsadi'},
#  {'admires', 'misread', 'sedarim', 'sidearm'},
#  {'adores', 'oreads', 'sarode', 'soared'},
#  {'adsorb', 'boards', 'broads', 'dobras'},
#  {'aery', 'eyra', 'yare', 'year'},
#  {'aether', 'heater', 'hereat', 'reheat'},
#  {'agentries', 'gratinees', 'reseating', 'stingaree'},
#  {'aginners', 'earnings', 'engrains', 'grannies'},
#  {'agree', 'eager', 'eagre', 'ragee'},
#  {'aids', 'dais', 'sadi', 'said'},
#  {'airest', 'satire', 'striae', 'terais'},
#  {'airshed', 'dashier', 'hardies', 'shadier'},
#  {'albs', 'bals', 'labs', 'slab'},
#  {'alef', 'feal', 'flea', 'leaf'},
#  {'alefs', 'false', 'fleas', 'leafs'},
#  {'alerted', 'altered', 'related', 'treadle'},
#  {'alerter', 'alterer', 'realter', 'relater'},
#  {'algor', 'argol', 'goral', 'largo'},
#  {'algors', 'argols', 'gorals', 'largos'},
#  {'alit', 'lati', 'tail', 'tali'},
#  {'allergy', 'gallery', 'largely', 'regally'},
#  {'alme', 'lame', 'male', 'meal'},
#  {'almes', 'lames', 'males', 'meals'},
#  {'alpines', 'pineals', 'spaniel', 'splenia'},
#  {'alpinist', 'antislip', 'pintails', 'tailspin'},
#  {'altar', 'artal', 'ratal', 'talar'},
#  {'amain', 'amnia', 'anima', 'mania'},
#  {'amender', 'meander', 'reedman', 'renamed'},
#  {'amps', 'maps', 'pams', 'samp'},
#  {'ancients', 'canniest', 'insectan', 'instance'},
#  {'anglesite', 'galenites', 'gelatines', 'teaseling'},
#  {'angst', 'gnats', 'stang', 'tangs'},
#  {'anils', 'nails', 'slain', 'snail'},
#  {'ankhs', 'hanks', 'khans', 'shank'},
#  {'anosmic', 'camions', 'maniocs', 'masonic'},
#  {'anthesis', 'shanties', 'sheitans', 'sthenias'},
#  {'antlers', 'rentals', 'saltern', 'sternal'},
#  {'aorist', 'aristo', 'ratios', 'satori'},
#  {'aplites', 'paliest', 'platies', 'talipes'},
#  {'aproned', 'operand', 'padrone', 'pandore'},
#  {'apses', 'pases', 'passe', 'spaes'},
#  {'aptly', 'patly', 'platy', 'typal'},
#  {'arbored', 'boarder', 'broader', 'reboard'},
#  {'arcked', 'carked', 'dacker', 'racked'},
#  {'argentic', 'catering', 'creating', 'reacting'},
#  {'argentites', 'estreating', 'integrates', 'interstage'},
#  {'argles', 'glares', 'lagers', 'larges'},
#  {'argon', 'groan', 'orang', 'organ'},
#  {'argus', 'gaurs', 'guars', 'sugar'},
#  {'arista', 'riatas', 'tarsia', 'tiaras'},
#  {'armed', 'derma', 'dream', 'madre'},
#  {'armet', 'mater', 'ramet', 'tamer'},
#  {'arrested', 'retreads', 'serrated', 'treaders'},
#  {'arsenites', 'irateness', 'resinates', 'stearines'},
#  {'artiness', 'retsinas', 'stainers', 'stearins'},
#  {'artist', 'strait', 'strati', 'traits'},
#  {'artless', 'lasters', 'salters', 'slaters'},
#  {'artsy', 'satyr', 'stray', 'trays'},
#  {'ascent', 'enacts', 'secant', 'stance'},
#  {'ashlering', 'narghiles', 'nargilehs', 'shearling'},
#  {'ashless', 'hassels', 'hassles', 'slashes'},
#  {'asker', 'eskar', 'rakes', 'saker'},
#  {'asp', 'pas', 'sap', 'spa'},
#  {'aspersing', 'grapiness', 'preassign', 'repassing'},
#  {'aspire', 'paries', 'praise', 'spirea'},
#  {'aspired', 'despair', 'diapers', 'praised'},
#  {'asps', 'pass', 'saps', 'spas'},
#  {'assentor', 'senators', 'starnose', 'treasons'},
#  {'asserter', 'reassert', 'serrates', 'terrases'},
#  {'astilbes', 'bastiles', 'blasties', 'stabiles'},
#  {'ateliers', 'earliest', 'leariest', 'realties'},
#  {'atingle', 'elating', 'gelatin', 'genital'},
#  {'aures', 'urase', 'ureas', 'ursae'},
#  {'averts', 'starve', 'traves', 'vaster'},
#  {'awned', 'dawen', 'dewan', 'waned'},
#  {'ayes', 'easy', 'eyas', 'yeas'},
#  {'bagel', 'belga', 'gable', 'gleba'},
#  {'baiter', 'barite', 'rebait', 'terbia'},
#  {'baiters', 'barites', 'rebaits', 'terbias'},
#  {'baker', 'brake', 'break', 'kebar'},
#  {'bakers', 'brakes', 'breaks', 'kebars'},
#  {'balmiest', 'bimetals', 'lambiest', 'timbales'},
#  {'bard', 'brad', 'darb', 'drab'},
#  {'bards', 'brads', 'darbs', 'drabs'},
#  {'barest', 'baster', 'breast', 'tabers'},
#  {'baritone', 'obtainer', 'reobtain', 'taborine'},
#  {'baritones', 'obtainers', 'reobtains', 'taborines'},
#  {'basest', 'basset', 'bastes', 'beasts'},
#  {'bast', 'bats', 'stab', 'tabs'},
#  {'berated', 'debater', 'rebated', 'tabered'},
#  {'biders', 'brides', 'debris', 'rebids'},
#  {'biers', 'birse', 'bries', 'ribes'},
#  {'binder', 'brined', 'inbred', 'rebind'},
#  {'boast', 'boats', 'botas', 'sabot'},
#  {'bolar', 'boral', 'labor', 'lobar'},
#  {'bores', 'brose', 'robes', 'sober'},
#  {'botanies', 'botanise', 'niobates', 'obeisant'},
#  {'bros', 'orbs', 'robs', 'sorb'},
#  {'bruise', 'buries', 'busier', 'rubies'},
#  {'brumal', 'labrum', 'lumbar', 'umbral'},
#  {'brunets', 'bunters', 'burnets', 'subrent'},
#  {'brute', 'buret', 'rebut', 'tuber'},
#  {'burbles', 'lubbers', 'rubbles', 'slubber'},
#  {'burse', 'rebus', 'rubes', 'suber'},
#  {'bust', 'buts', 'stub', 'tubs'},
#  {'cadres', 'cedars', 'sacred', 'scared'},
#  {'callers', 'cellars', 'recalls', 'scleral'},
#  {'calo', 'coal', 'cola', 'loca'},
#  {'calorie', 'cariole', 'coalier', 'loricae'},
#  {'caner', 'crane', 'nacre', 'rance'},
#  {'cantered', 'crenated', 'decanter', 'recanted'},
#  {'cantor', 'carton', 'contra', 'craton'},
#  {'cantors', 'cartons', 'contras', 'cratons'},
#  {'caper', 'crape', 'pacer', 'recap'},
#  {'capes', 'paces', 'scape', 'space'},
#  {'capitol', 'coalpit', 'optical', 'topical'},
#  {'capsule', 'scaleup', 'specula', 'upscale'},
#  {'carless', 'classer', 'scalers', 'scleras'},
#  {'carpets', 'preacts', 'precast', 'spectra'},
#  {'carps', 'craps', 'scarp', 'scrap'},
#  {'carted', 'crated', 'redact', 'traced'},
#  {'cartels', 'clarets', 'crestal', 'scarlet'},
#  {'caste', 'cates', 'cesta', 'taces'},
#  {'catered', 'cerated', 'created', 'reacted'},
#  {'caterer', 'recrate', 'retrace', 'terrace'},
#  {'caterers', 'recrates', 'retraces', 'terraces'},
#  {'cedarn', 'craned', 'dancer', 'nacred'},
#  {'censored', 'encoders', 'necrosed', 'seconder'},
#  {'censual', 'lacunes', 'launces', 'unlaces'},
#  {'centares', 'reascent', 'reenacts', 'sarcenet'},
#  {'center', 'centre', 'recent', 'tenrec'},
#  {'centiare', 'creatine', 'increate', 'iterance'},
#  {'ceramist', 'matrices', 'mistrace', 'scimetar'},
#  {'cereals', 'relaces', 'rescale', 'sclerae'},
#  {'ceros', 'cores', 'corse', 'score'},
#  {'cerous', 'course', 'crouse', 'source'},
#  {'ceruses', 'recuses', 'rescues', 'secures'},
#  {'cerusites', 'cerussite', 'curtesies', 'icteruses'},
#  {'cestos', 'cosets', 'cosset', 'escots'},
#  {'chanters', 'snatcher', 'stancher', 'tranches'},
#  {'cheat', 'tache', 'teach', 'theca'},
#  {'cheaters', 'hectares', 'recheats', 'teachers'},
#  {'cheero', 'cohere', 'echoer', 'reecho'},
#  {'cheeros', 'coheres', 'echoers', 'rechose'},
#  {'chiels', 'chiles', 'chisel', 'liches'},
#  {'chiros', 'choirs', 'ichors', 'orchis'},
#  {'chitties', 'ethicist', 'itchiest', 'theistic'},
#  {'chores', 'cosher', 'ochers', 'ochres'},
#  {'christen', 'citherns', 'cithrens', 'snitcher'},
#  {'cider', 'cried', 'dicer', 'riced'},
#  {'cion', 'coin', 'coni', 'icon'},
#  {'cirrose', 'corries', 'crosier', 'orrices'},
#  {'citadel', 'deltaic', 'dialect', 'edictal'},
#  {'citrine', 'crinite', 'inciter', 'neritic'},
#  {'claimed', 'decimal', 'declaim', 'medical'},
#  {'cleared', 'creedal', 'declare', 'relaced'},
#  {'coder', 'cored', 'credo', 'decor'},
#  {'coders', 'credos', 'decors', 'scored'},
#  {'coiners', 'cronies', 'orceins', 'recoins'},
#  {'coinfers', 'conifers', 'forensic', 'fornices'},
#  {'colters', 'corslet', 'costrel', 'lectors'},
#  {'conies', 'cosine', 'icones', 'oscine'},
#  {'construe', 'counters', 'recounts', 'trounces'},
#  {'contours', 'cornutos', 'croutons', 'outscorn'},
#  {'corked', 'docker', 'redock', 'rocked'},
#  {'cornute', 'counter', 'recount', 'trounce'},
#  {'corselet', 'electors', 'electros', 'selector'},
#  {'courantes', 'courtesan', 'nectarous', 'outrances'},
#  {'crakes', 'creaks', 'sacker', 'screak'},
#  {'cratered', 'recrated', 'retraced', 'terraced'},
#  {'cratering', 'recrating', 'retracing', 'terracing'},
#  {'cripes', 'precis', 'prices', 'spicer'},
#  {'crispate', 'paretics', 'picrates', 'practise'},
#  {'cruses', 'curses', 'cusser', 'sucres'},
#  {'cuneal', 'lacune', 'launce', 'unlace'},
#  {'dale', 'deal', 'lade', 'lead'},
#  {'damneder', 'demander', 'redemand', 'remanded'},
#  {'danger', 'gander', 'garden', 'ranged'},
#  {'dangered', 'deranged', 'gandered', 'gardened'},
#  {'dangering', 'deranging', 'gandering', 'gardening'},
#  {'dangles', 'glandes', 'lagends', 'slanged'},
#  {'danker', 'darken', 'narked', 'ranked'},
#  {'dares', 'dears', 'rased', 'reads'},
#  {'darnels', 'landers', 'slander', 'snarled'},
#  {'darter', 'retard', 'tarred', 'trader'},
#  {'darters', 'retards', 'starred', 'traders'},
#  {'dashes', 'sadhes', 'sashed', 'shades'},
#  {'daunter', 'natured', 'unrated', 'untread'},
#  {'dearest', 'derates', 'redates', 'sedater'},
#  {'deary', 'deray', 'rayed', 'ready'},
#  {'dedans', 'desand', 'sadden', 'sanded'},
#  {'delivers', 'desilver', 'silvered', 'slivered'},
#  {'dens', 'ends', 'send', 'sned'},
#  {'denser', 'enders', 'resend', 'sender'},
#  {'dentin', 'indent', 'intend', 'tinned'},
#  {'dentures', 'sederunt', 'underset', 'unrested'},
#  {'denude', 'dudeen', 'duende', 'endued'},
#  {'depart', 'parted', 'petard', 'prated'},
#  {'depots', 'despot', 'posted', 'stoped'},
#  {'deraign', 'gradine', 'grained', 'reading'},
#  {'derating', 'gradient', 'redating', 'treading'},
#  {'derives', 'deviser', 'diverse', 'revised'},
#  {'derrises', 'desirers', 'dressier', 'residers'},
#  {'despoil', 'diploes', 'dipoles', 'spoiled'},
#  {'detour', 'redout', 'routed', 'toured'},
#  {'detours', 'dourest', 'redouts', 'rousted'},
#  {'devein', 'endive', 'envied', 'veined'},
#  {'devisor', 'devoirs', 'visored', 'voiders'},
#  {'diaper', 'paired', 'pardie', 'repaid'},
#  {'diester', 'dieters', 'reedits', 'resited'},
#  {'diesters', 'editress', 'resisted', 'sistered'},
#  {'dieter', 'reedit', 'retied', 'tiered'},
#  {'dinar', 'drain', 'nadir', 'ranid'},
#  {'dinars', 'drains', 'nadirs', 'ranids'},
#  {'diopter', 'dioptre', 'peridot', 'proteid'},
#  {'discounter', 'introduces', 'rediscount', 'reductions'},
#  {'dispel', 'lisped', 'sliped', 'spiled'},
#  {'doer', 'dore', 'redo', 'rode'},
#  {'donator', 'odorant', 'tandoor', 'tornado'},
#  {'door', 'odor', 'ordo', 'rood'},
#  {'doors', 'odors', 'ordos', 'roods'},
#  {'doper', 'pedro', 'pored', 'roped'},
#  {'dopers', 'pedros', 'prosed', 'spored'},
#  {'doters', 'sorted', 'stored', 'strode'},
#  {'dotier', 'editor', 'rioted', 'triode'},
#  {'doubter', 'obtrude', 'outbred', 'redoubt'},
#  {'douser', 'roused', 'soured', 'uredos'},
#  {'drail', 'laird', 'liard', 'lidar'},
#  {'drails', 'lairds', 'liards', 'lidars'},
#  {'drape', 'padre', 'pared', 'raped'},
#  {'drawers', 'redraws', 'rewards', 'warders'},
#  {'dreeing', 'energid', 'reeding', 'reigned'},
#  {'dries', 'resid', 'rides', 'sired'},
#  {'drogue', 'gourde', 'rogued', 'rouged'},
#  {'drupe', 'duper', 'perdu', 'prude'},
#  {'duramen', 'manured', 'maunder', 'unarmed'},
#  {'eaglet', 'gelate', 'legate', 'telega'},
#  {'earl', 'lear', 'rale', 'real'},
#  {'early', 'layer', 'leary', 'relay'},
#  {'earth', 'hater', 'heart', 'rathe'},
#  {'eels', 'else', 'lees', 'seel'},
#  {'egers', 'grees', 'reges', 'serge'},
#  {'elands', 'ladens', 'naleds', 'sendal'},
#  {'elastins', 'nailsets', 'salients', 'saltines'},
#  {'elaterins', 'entailers', 'nearliest', 'treenails'},
#  {'elisions', 'isolines', 'lionises', 'oiliness'},
#  {'eloigns', 'legions', 'lingoes', 'longies'},
#  {'eloins', 'insole', 'lesion', 'oleins'},
#  {'emirs', 'mires', 'miser', 'rimes'},
#  {'emit', 'item', 'mite', 'time'},
#  {'emprises', 'impreses', 'premises', 'spiremes'},
#  {'enduros', 'resound', 'sounder', 'undoers'},
#  {'energies', 'energise', 'greenies', 'reseeing'},
#  {'engram', 'german', 'manger', 'ragmen'},
#  {'enlister', 'listener', 'reenlist', 'silenter'},
#  {'enlists', 'listens', 'silents', 'tinsels'},
#  {'enol', 'leno', 'lone', 'noel'},
#  {'entases', 'sateens', 'senates', 'sensate'},
#  {'enter', 'rente', 'terne', 'treen'},
#  {'enterer', 'reenter', 'terreen', 'terrene'},
#  {'enterers', 'reenters', 'terreens', 'terrenes'},
#  {'entires', 'entries', 'retines', 'trienes'},
#  {'entree', 'eterne', 'retene', 'teener'},
#  {'ephas', 'heaps', 'phase', 'shape'},
#  {'epistler', 'peltries', 'perlites', 'reptiles'},
#  {'epos', 'opes', 'peso', 'pose'},
#  {'erections', 'neoterics', 'resection', 'secretion'},
#  {'erethic', 'etheric', 'heretic', 'techier'},
#  {'ergo', 'goer', 'gore', 'ogre'},
#  {'eringos', 'ignores', 'regions', 'signore'},
#  {'erotism', 'moister', 'mortise', 'trisome'},
#  {'ervil', 'liver', 'livre', 'viler'},
#  {'espials', 'lapises', 'lipases', 'palsies'},
#  {'estrus', 'russet', 'surest', 'tusser'},
#  {'evil', 'live', 'veil', 'vile'},
#  {'evilness', 'liveness', 'veinless', 'vileness'},
#  {'ewers', 'resew', 'sewer', 'sweer'},
#  {'eyras', 'resay', 'sayer', 'years'},
#  {'fates', 'feast', 'feats', 'fetas'},
#  {'felid', 'field', 'filed', 'flied'},
#  {'ferlie', 'liefer', 'refile', 'relief'},
#  {'ferlies', 'refiles', 'reflies', 'reliefs'},
#  {'filer', 'flier', 'lifer', 'rifle'},
#  {'filers', 'fliers', 'lifers', 'rifles'},
#  {'filters', 'lifters', 'stifler', 'trifles'},
#  {'finder', 'friend', 'redfin', 'refind'},
#  {'finders', 'friends', 'redfins', 'refinds'},
#  {'flower', 'fowler', 'reflow', 'wolfer'},
#  {'flowers', 'fowlers', 'reflows', 'wolfers'},
#  {'gagster', 'gargets', 'stagger', 'taggers'},
#  {'gamier', 'imager', 'maigre', 'mirage'},
#  {'gaper', 'grape', 'pager', 'parge'},
#  {'gast', 'gats', 'stag', 'tags'},
#  {'gastrin', 'gratins', 'ratings', 'staring'},
#  {'gateman', 'magenta', 'magnate', 'nametag'},
#  {'gentries', 'integers', 'reesting', 'steering'},
#  {'gingers', 'niggers', 'serging', 'snigger'},
#  {'girts', 'grist', 'grits', 'trigs'},
#  {'gledes', 'gleeds', 'ledges', 'sledge'},
#  {'gluier', 'ligure', 'reguli', 'uglier'},
#  {'gnarliest', 'integrals', 'reslating', 'triangles'},
#  {'gnus', 'guns', 'snug', 'sung'},
#  {'goers', 'gores', 'gorse', 'ogres'},
#  {'grantee', 'greaten', 'negater', 'reagent'},
#  {'gunshot', 'hognuts', 'noughts', 'shotgun'},
#  {'gush', 'hugs', 'sugh', 'ughs'},
#  {'haets', 'haste', 'hates', 'heats'},
#  {'halest', 'haslet', 'lathes', 'shelta'},
#  {'hasped', 'pashed', 'phased', 'shaped'},
#  {'hasping', 'pashing', 'phasing', 'shaping'},
#  {'heirs', 'hires', 'shier', 'shire'},
#  {'helos', 'holes', 'hosel', 'sheol'},
#  {'helots', 'hostel', 'hotels', 'tholes'},
#  {'hematics', 'mastiche', 'misteach', 'tachisme'},
#  {'herons', 'honers', 'nosher', 'senhor'},
#  {'hins', 'hisn', 'shin', 'sinh'},
#  {'hips', 'phis', 'pish', 'ship'},
#  {'hops', 'posh', 'shop', 'soph'},
#  {'hordes', 'horsed', 'reshod', 'shored'},
#  {'horste', 'others', 'reshot', 'throes'},
#  {'huts', 'shut', 'thus', 'tush'},
#  {'hypnotic', 'phytonic', 'pythonic', 'typhonic'},
#  {'imarets', 'maestri', 'misrate', 'smartie'},
#  {'impaler', 'impearl', 'lempira', 'palmier'},
#  {'impress', 'premiss', 'simpers', 'spirems'},
#  {'inapt', 'paint', 'patin', 'pinta'},
#  {'ingress', 'resigns', 'signers', 'singers'},
#  {'inks', 'kins', 'sink', 'skin'},
#  {'inro', 'iron', 'noir', 'nori'},
#  {'insetter', 'interest', 'sternite', 'trientes'},
#  {'insetters', 'interests', 'sternites', 'triteness'},
#  {'instar', 'santir', 'strain', 'trains'},
#  {'intreats', 'nitrates', 'straiten', 'tertians'},
#  {'intrude', 'turdine', 'untired', 'untried'},
#  {'ires', 'reis', 'rise', 'sire'},
#  {'irks', 'kirs', 'kris', 'risk'},
#  {'isatines', 'sanities', 'sanitise', 'teniasis'},
#  {'islet', 'istle', 'stile', 'tiles'},
#  {'islets', 'istles', 'sliest', 'stiles'},
#  {'kales', 'lakes', 'leaks', 'slake'},
#  {'kanes', 'skean', 'snake', 'sneak'},
#  {'karn', 'knar', 'nark', 'rank'},
#  {'keens', 'knees', 'skeen', 'skene'},
#  {'keirs', 'kiers', 'siker', 'skier'},
#  {'kitsch', 'schtik', 'shtick', 'thicks'},
#  {'koas', 'oaks', 'okas', 'soak'},
#  {'lament', 'mantel', 'mantle', 'mental'},
#  {'lamister', 'marliest', 'marlites', 'misalter'},
#  {'lamps', 'palms', 'plasm', 'psalm'},
#  {'lanais', 'lianas', 'nasial', 'salina'},
#  {'lapsed', 'padles', 'pedals', 'pleads'},
#  {'lascars', 'rascals', 'sacrals', 'scalars'},
#  {'lasting', 'salting', 'slating', 'staling'},
#  {'laveer', 'leaver', 'reveal', 'vealer'},
#  {'leap', 'pale', 'peal', 'plea'},
#  {'lefter', 'refelt', 'reflet', 'telfer'},
#  {'letters', 'settler', 'sterlet', 'trestle'},
#  {'lier', 'lire', 'riel', 'rile'},
#  {'liers', 'riels', 'riles', 'slier'},
#  {'limes', 'miles', 'slime', 'smile'},
#  {'limpers', 'prelims', 'rimples', 'simpler'},
#  {'lineups', 'lupines', 'spinule', 'unpiles'},
#  {'lino', 'lion', 'loin', 'noil'},
#  {'linos', 'lions', 'loins', 'noils'},
#  {'lisping', 'pilings', 'sliping', 'spiling'},
#  {'liter', 'litre', 'relit', 'tiler'},
#  {'loess', 'loses', 'sloes', 'soles'},
#  {'loons', 'nolos', 'snool', 'solon'},
#  {'lories', 'oilers', 'oriels', 'reoils'},
#  {'lose', 'oles', 'sloe', 'sole'},
#  {'maches', 'sachem', 'samech', 'schema'},
#  {'maes', 'mesa', 'same', 'seam'},
#  {'magister', 'migrates', 'ragtimes', 'sterigma'},
#  {'maidens', 'medians', 'medinas', 'sideman'},
#  {'maintop', 'ptomain', 'tampion', 'timpano'},
#  {'mangiest', 'mintages', 'misagent', 'steaming'},
#  {'manors', 'ramson', 'ransom', 'romans'},
#  {'marshes', 'mashers', 'shmears', 'smasher'},
#  {'melters', 'remelts', 'resmelt', 'smelter'},
#  {'mense', 'mesne', 'neems', 'semen'},
#  {'merest', 'meters', 'metres', 'retems'},
#  {'merriest', 'miterers', 'rimester', 'triremes'},
#  {'meter', 'metre', 'remet', 'retem'},
#  {'metiers', 'reemits', 'retimes', 'triseme'},
#  {'minuets', 'minutes', 'mistune', 'mutines'},
#  {'miseats', 'misseat', 'samites', 'tamises'},
#  {'misset', 'smites', 'stimes', 'tmesis'},
#  {'moste', 'motes', 'smote', 'tomes'},
#  {'must', 'muts', 'smut', 'stum'},
#  {'nape', 'neap', 'pane', 'pean'},
#  {'naps', 'pans', 'snap', 'span'},
#  {'nereis', 'seiner', 'serein', 'serine'},
#  {'nerts', 'rents', 'stern', 'terns'},
#  {'nest', 'nets', 'sent', 'tens'},
#  {'neuter', 'retune', 'tenure', 'tureen'},
#  {'neuters', 'retunes', 'tenures', 'tureens'},
#  {'nipa', 'pain', 'pian', 'pina'},
#  {'nipas', 'pains', 'pians', 'pinas'},
#  {'nips', 'pins', 'snip', 'spin'},
#  {'nonets', 'sonnet', 'tenons', 'tonnes'},
#  {'nope', 'open', 'peon', 'pone'},
#  {'norites', 'oestrin', 'orients', 'stonier'},
#  {'notal', 'talon', 'tolan', 'tonal'},
#  {'noter', 'tenor', 'toner', 'trone'},
#  {'oars', 'osar', 'soar', 'sora'},
#  {'oast', 'oats', 'stoa', 'taos'},
#  {'oils', 'silo', 'soil', 'soli'},
#  {'onsets', 'setons', 'stenos', 'stones'},
#  {'openest', 'pentose', 'posteen', 'poteens'},
#  {'orpins', 'prions', 'prison', 'spinor'},
#  {'orts', 'rots', 'sort', 'tors'},
#  {'otter', 'rotte', 'torte', 'toter'},
#  {'otters', 'rottes', 'tortes', 'toters'},
#  {'ousting', 'outings', 'outsing', 'tousing'},
#  {'outgrin', 'outring', 'routing', 'touring'},
#  {'outgrins', 'outrings', 'rousting', 'tourings'},
#  {'outskate', 'outtakes', 'stakeout', 'takeouts'},
#  {'overs', 'roves', 'servo', 'verso'},
#  {'owners', 'resown', 'rowens', 'worsen'},
#  {'padle', 'paled', 'pedal', 'plead'},
#  {'paints', 'patins', 'pintas', 'ptisan'},
#  {'panel', 'penal', 'plane', 'plena'},
#  {'panties', 'patines', 'sapient', 'spinate'},
#  {'parables', 'parsable', 'prebasal', 'sparable'},
#  {'parental', 'parlante', 'paternal', 'prenatal'},
#  {'parings', 'parsing', 'rasping', 'sparing'},
#  {'parley', 'pearly', 'player', 'replay'},
#  {'parroted', 'predator', 'prorated', 'teardrop'},
#  {'pars', 'raps', 'rasp', 'spar'},
#  {'parsers', 'raspers', 'sparers', 'sparser'},
#  {'partans', 'spartan', 'tarpans', 'trapans'},
#  {'past', 'pats', 'spat', 'taps'},
#  {'pasties', 'patsies', 'petsais', 'tapises'},
#  {'pastina', 'patinas', 'pinatas', 'taipans'},
#  {'pasture', 'uprates', 'upstare', 'uptears'},
#  {'pate', 'peat', 'tape', 'tepa'},
#  {'pathoses', 'potashes', 'spathose', 'teashops'},
#  {'paws', 'swap', 'waps', 'wasp'},
#  {'pays', 'pyas', 'spay', 'yaps'},
#  {'pederast', 'predates', 'repasted', 'trapesed'},
#  {'peels', 'peles', 'sleep', 'speel'},
#  {'pelters', 'petrels', 'respelt', 'spelter'},
#  {'penster', 'present', 'repents', 'serpent'},
#  {'pensters', 'pertness', 'presents', 'serpents'},
#  {'perries', 'prisere', 'reprise', 'respire'},
#  {'persalts', 'plasters', 'psalters', 'staplers'},
#  {'persistent', 'pinsetters', 'presentist', 'prettiness'},
#  {'pest', 'pets', 'sept', 'step'},
#  {'petrale', 'pleater', 'prelate', 'replate'},
#  {'petrales', 'pleaters', 'prelates', 'replates'},
#  {'phrases', 'seraphs', 'shapers', 'sherpas'},
#  {'piecers', 'pierces', 'precise', 'recipes'},
#  {'pinot', 'pinto', 'piton', 'point'},
#  {'pointers', 'porniest', 'proteins', 'tropines'},
#  {'ports', 'prost', 'sport', 'strop'},
#  {'posters', 'prestos', 'respots', 'stopers'},
#  {'pouter', 'roupet', 'troupe', 'uptore'},
#  {'presplit', 'ripplets', 'stippler', 'tipplers'},
#  {'pride', 'pried', 'redip', 'riped'},
#  {'prostie', 'reposit', 'riposte', 'ropiest'},
#  {'questor', 'quoters', 'roquets', 'torques'},
#  {'rato', 'rota', 'taro', 'tora'},
#  {'rawest', 'tawers', 'waster', 'waters'},
#  {'reserve', 'reveres', 'reverse', 'severer'},
#  {'resilver', 'revilers', 'silverer', 'sliverer'},
#  {'resins', 'rinses', 'serins', 'sirens'},
#  {'resort', 'retros', 'roster', 'sorter'},
#  {'resows', 'serows', 'sowers', 'worses'},
#  {'retest', 'setter', 'street', 'tester'},
#  {'reticles', 'sclerite', 'tiercels', 'triscele'},
#  {'rhesus', 'rhuses', 'rushes', 'ushers'},
#  {'rillets', 'stiller', 'tillers', 'trellis'},
#  {'rites', 'tiers', 'tires', 'tries'},
#  {'rives', 'siver', 'viers', 'vires'},
#  {'rivets', 'stiver', 'strive', 'verist'},
#  {'rouster', 'routers', 'tourers', 'trouser'},
#  {'rowths', 'throws', 'whorts', 'worths'},
#  {'ruinate', 'taurine', 'uranite', 'urinate'},
#  {'ruinates', 'taurines', 'uranites', 'urinates'},
#  {'ryot', 'tory', 'troy', 'tyro'},
#  {'salves', 'selvas', 'slaves', 'valses'},
#  {'serve', 'sever', 'veers', 'verse'},
#  {'sett', 'stet', 'test', 'tets'},
#  {'sitter', 'titers', 'titres', 'triste'},
#  {'skater', 'strake', 'streak', 'takers'},
#  {'skating', 'staking', 'takings', 'tasking'},
#  {'spirts', 'sprits', 'stirps', 'strips'},
#  {'spouts', 'stoups', 'tossup', 'uptoss'},
#  {'stew', 'tews', 'west', 'wets'},
#  {'stickler', 'strickle', 'ticklers', 'trickles'},
#  {'stoker', 'stroke', 'tokers', 'trokes'},
#  {'stover', 'strove', 'troves', 'voters'},
#  {'strow', 'trows', 'worst', 'worts'},
#  {'sweat', 'tawse', 'twaes', 'waste'},
#  {'waister', 'waiters', 'wariest', 'wastrie'},
#  {'warstles', 'wartless', 'wastrels', 'wrastles'},
#  {'weird', 'wider', 'wired', 'wried'},
#  {'weirs', 'wires', 'wiser', 'wries'},
#  {'abed', 'bade', 'bead'},
#  {'abettals', 'statable', 'tastable'},
#  {'able', 'bale', 'blae'},
#  {'ablutions', 'abutilons', 'sublation'},
#  {'abort', 'boart', 'tabor'},
#  {'aborted', 'borated', 'tabored'},
#  {'aborting', 'borating', 'taboring'},
#  {'aborts', 'boarts', 'tabors'},
#  {'abreact', 'bearcat', 'cabaret'},
#  {'abs', 'bas', 'sab'},
#  {'abscise', 'scabies', 'sebasic'},
#  {'abusers', 'rubasse', 'surbase'},
#  {'abut', 'tabu', 'tuba'},
#  {'acarids', 'ascarid', 'cardias'},
#  {'acarines', 'canaries', 'cesarian'},
#  {'accouters', 'accoutres', 'coruscate'},
#  {'accruals', 'caraculs', 'saccular'},
#  {'aced', 'cade', 'dace'},
#  {'acerb', 'brace', 'caber'},
#  {'acid', 'cadi', 'caid'},
#  {'acme', 'came', 'mace'},
#  {'acmes', 'cames', 'maces'},
#  {'acned', 'caned', 'dance'},
#  {'acnes', 'canes', 'scena'},
#  {'acnode', 'canoed', 'deacon'},
#  {'aconites', 'canoeist', 'sonicate'},
#  {'acorn', 'narco', 'racon'},
#  {'acorns', 'narcos', 'racons'},
#  {'acrasin', 'arnicas', 'carinas'},
#  {'acre', 'care', 'race'},
#  {'acrid', 'caird', 'daric'},
#  {'actinide', 'ctenidia', 'indicate'},
#  {'actinides', 'andesitic', 'indicates'},
#  {'actins', 'antics', 'nastic'},
#  {'action', 'atonic', 'cation'},
#  {'actionless', 'coastlines', 'sectionals'},
#  {'actions', 'atonics', 'cations'},
#  {'activations', 'cavitations', 'vacationist'},
#  {'actorish', 'chariots', 'haricots'},
#  {'actress', 'casters', 'recasts'},
#  {'acyl', 'clay', 'lacy'},
#  {'acyls', 'clays', 'scaly'},
#  {'addle', 'dedal', 'laded'},
#  {'adeems', 'edemas', 'seamed'},
#  {'adept', 'pated', 'taped'},
#  {'admirers', 'disarmer', 'marrieds'},
#  {'admonisher', 'harmonised', 'rhodamines'},
#  {'adopters', 'pastored', 'readopts'},
#  {'adore', 'oared', 'oread'},
#  {'adroitly', 'dilatory', 'idolatry'},
#  {'adsorber', 'boarders', 'reboards'},
#  {'adsorbing', 'boardings', 'signboard'},
#  {'advise', 'davies', 'visaed'},
#  {'aeried', 'dearie', 'rediae'},
#  {'aeroduct', 'educator', 'outraced'},
#  {'aeroducts', 'croustade', 'educators'},
#  {'aethers', 'heaters', 'reheats'},
#  {'afebrile', 'balefire', 'fireable'},
#  {'afters', 'faster', 'strafe'},
#  {'aged', 'egad', 'gaed'},
#  {'ager', 'gear', 'rage'},
#  {'ages', 'gaes', 'sage'},
#  {'agger', 'eggar', 'gager'},
#  {'aggress', 'saggers', 'seggars'},
#  {'agist', 'gaits', 'staig'},
#  {'aglare', 'alegar', 'laager'},
#  {'agnostic', 'coasting', 'coatings'},
#  {'agreed', 'dragee', 'geared'},
#  {'agrestic', 'cigarets', 'ergastic'},
#  {'ahem', 'haem', 'hame'},
#  {'ahorse', 'ashore', 'hoarse'},
#  {'aides', 'aside', 'ideas'},
#  {'aiglet', 'gelati', 'ligate'},
#  {'aigret', 'gaiter', 'triage'},
#  {'ails', 'sail', 'sial'},
#  {'aimed', 'amide', 'media'},
#  {'aimers', 'armies', 'ramies'},
#  {'aimless', 'samiels', 'seismal'},
#  {'aims', 'amis', 'sima'},
#  {'ains', 'anis', 'sain'},
#  {'airdate', 'radiate', 'tiaraed'},
#  {'airdates', 'dataries', 'radiates'},
#  {'airers', 'raiser', 'sierra'},
#  {'airings', 'arising', 'raising'},
#  {'airmen', 'marine', 'remain'},
#  {'airn', 'rain', 'rani'},
#  {'airposts', 'prosaist', 'protasis'},
#  {'airs', 'rias', 'sari'},
#  {'akin', 'kain', 'kina'},
#  {'alans', 'anlas', 'nasal'},
#  {'alb', 'bal', 'lab'},
#  {'albata', 'atabal', 'balata'},
#  {'albatas', 'atabals', 'balatas'},
#  {'albicore', 'braciole', 'cabriole'},
#  {'albicores', 'bracioles', 'cabrioles'},
#  {'alecs', 'laces', 'scale'},
#  {'algerines', 'releasing', 'resealing'},
#  {'alible', 'labile', 'liable'},
#  {'alienators', 'rationales', 'senatorial'},
#  {'alif', 'fail', 'fila'},
#  {'aligned', 'dealing', 'leading'},
#  {'alined', 'denial', 'nailed'},
#  {'aliners', 'nailers', 'renails'},
#  {'aliped', 'elapid', 'pleiad'},
#  {'alist', 'litas', 'tails'},
#  {'alliance', 'ancillae', 'canaille'},
#  {'allotypic', 'optically', 'topically'},
#  {'almah', 'halma', 'hamal'},
#  {'almahs', 'halmas', 'hamals'},
#  {'almost', 'smalto', 'stomal'},
#  {'alms', 'lams', 'slam'},
#  {'aloft', 'float', 'flota'},
#  {'alp', 'lap', 'pal'},
#  {'alpine', 'penial', 'pineal'},
#  {'als', 'las', 'sal'},
#  {'alterants', 'tarletans', 'translate'},
#  {'alterers', 'realters', 'relaters'},
#  {'altho', 'loath', 'lotah'},
#  {'alto', 'lota', 'tola'},
#  {'altos', 'lotas', 'tolas'},
#  {'altruism', 'muralist', 'ultraism'},
#  {'altruisms', 'muralists', 'ultraisms'},
#  {'altruist', 'titulars', 'ultraist'},
#  {'alumin', 'alumni', 'lumina'},
#  {'amber', 'bream', 'embar'},
#  {'ambers', 'breams', 'embars'},
#  {'ambling', 'blaming', 'lambing'},
#  {'ameers', 'ramees', 'seamer'},
#  {'amends', 'desman', 'menads'},
#  {'ament', 'meant', 'menta'},
#  {'aments', 'mantes', 'stamen'},
#  {'amerced', 'creamed', 'racemed'},
#  {'amercers', 'creamers', 'screamer'},
#  {'amercing', 'creaming', 'germanic'},
#  {'amin', 'main', 'mina'},
#  {'amine', 'anime', 'minae'},
#  {'amins', 'mains', 'minas'},
#  {'amir', 'mair', 'rami'},
#  {'amirs', 'mairs', 'simar'},
#  {'amitoses', 'amosites', 'atomises'},
#  {'amnions', 'mansion', 'onanism'},
#  {'amosite', 'atomies', 'atomise'},
#  {'amp', 'map', 'pam'},
#  {'amusers', 'assumer', 'masseur'},
#  {'analcites', 'anelastic', 'laitances'},
#  {'anchor', 'archon', 'rancho'},
#  {'anchors', 'archons', 'ranchos'},
#  {'ancientries', 'creatinines', 'incinerates'},
#  {'aneled', 'leaden', 'leaned'},
#  {'aneling', 'eanling', 'leaning'},
#  {'anemic', 'cinema', 'iceman'},
#  {'anergias', 'angaries', 'arginase'},
#  {'anew', 'wane', 'wean'},
#  {'angel', 'angle', 'glean'},
#  {'angelic', 'anglice', 'galenic'},
#  {'angels', 'angles', 'gleans'},
#  {'angelus', 'lagunes', 'langues'},
#  {'anger', 'range', 'regna'},
#  {'angers', 'ranges', 'sanger'},
#  {'angled', 'dangle', 'lagend'},
#  {'anil', 'lain', 'nail'},
#  {'animal', 'lamina', 'manila'},
#  {'animals', 'laminas', 'manilas'},
#  {'animis', 'saimin', 'simian'},
#  {'animist', 'intimas', 'santimi'},
#  {'anises', 'sanies', 'sansei'},
#  {'anisette', 'tetanies', 'tetanise'},
#  {'ankh', 'hank', 'khan'},
#  {'anlages', 'galenas', 'lasagne'},
#  {'anna', 'naan', 'nana'},
#  {'annas', 'naans', 'nanas'},
#  {'anoints', 'nations', 'onanist'},
#  {'anomic', 'camion', 'manioc'},
#  {'anopias', 'anopsia', 'paisano'},
#  {'anoretic', 'creation', 'reaction'},
#  {'anoretics', 'creations', 'reactions'},
#  {'ante', 'etna', 'neat'},
#  {'anteing', 'antigen', 'gentian'},
#  {'antiars', 'artisan', 'tsarina'},
#  {'antimonials', 'laminations', 'nationalism'},
#  {'antipress', 'pinasters', 'pristanes'},
#  {'antired', 'detrain', 'trained'},
#  ...]

# %%
'michele'[::-1]
# Out:
# 'elehcim'

# %%
pairs = []

for wordset in anagrams_by_sig.values():
    for word1 in wordset:
        for word2 in wordset:
            if word1 >= word2 and word1[::-1] == word2:
                pairs.append((word1, word2))

# %%
pairs
# Out:
# [('aha', 'aha'),
#  ('ala', 'ala'),
#  ('ba', 'ab'),
#  ('aba', 'aba'),
#  ('abba', 'abba'),
#  ('sab', 'bas'),
#  ('tuba', 'abut'),
#  ('serac', 'cares'),
#  ('dad', 'dad'),
#  ('laded', 'dedal'),
#  ('soda', 'ados'),
#  ('raga', 'agar'),
#  ('saga', 'agas'),
#  ('senega', 'agenes'),
#  ('ha', 'ah'),
#  ('redia', 'aider'),
#  ('sima', 'amis'),
#  ('ria', 'air'),
#  ('stria', 'airts'),
#  ('raja', 'ajar'),
#  ('la', 'al'),
#  ('lab', 'bal'),
#  ('slab', 'bals'),
#  ('fila', 'alif'),
#  ('pal', 'lap'),
#  ('slap', 'pals'),
#  ('sal', 'las'),
#  ('ma', 'am'),
#  ('nema', 'amen'),
#  ('semina', 'animes'),
#  ('pam', 'map'),
#  ('na', 'an'),
#  ('regna', 'anger'),
#  ('stang', 'gnats'),
#  ('lamina', 'animal'),
#  ('anna', 'anna'),
#  ('naan', 'naan'),
#  ('nona', 'anon'),
#  ('etna', 'ante'),
#  ('dopa', 'apod'),
#  ('tap', 'pat'),
#  ('bra', 'arb'),
#  ('era', 'are'),
#  ('sera', 'ares'),
#  ('regal', 'lager'),
#  ('rial', 'lair'),
#  ('rail', 'liar'),
#  ('lira', 'aril'),
#  ('relaid', 'dialer'),
#  ('seral', 'lares'),
#  ('ram', 'mar'),
#  ('sirra', 'arris'),
#  ('tar', 'rat'),
#  ('star', 'rats'),
#  ('mura', 'arum'),
#  ('sap', 'pas'),
#  ('spas', 'saps'),
#  ('ta', 'at'),
#  ('tae', 'eat'),
#  ('eta', 'ate'),
#  ('seta', 'ates'),
#  ('sate', 'etas'),
#  ('tat', 'tat'),
#  ('skua', 'auks'),
#  ('laud', 'dual'),
#  ('diva', 'avid'),
#  ('ova', 'avo'),
#  ('wan', 'naw'),
#  ('wans', 'snaw'),
#  ('ya', 'ay'),
#  ('dab', 'bad'),
#  ('gab', 'bag'),
#  ('nab', 'ban'),
#  ('drab', 'bard'),
#  ('darb', 'brad'),
#  ('stab', 'bats'),
#  ('tab', 'bat'),
#  ('deb', 'bed'),
#  ('neb', 'ben'),
#  ('dib', 'bid'),
#  ('gib', 'big'),
#  ('nib', 'bin'),
#  ('snib', 'bins'),
#  ('drib', 'bird'),
#  ('sib', 'bis'),
#  ('bulb', 'blub'),
#  ('gob', 'bog'),
#  ('obol', 'lobo'),
#  ('knob', 'bonk'),
#  ('sob', 'bos'),
#  ('stob', 'bots'),
#  ('swob', 'bows'),
#  ('yob', 'boy'),
#  ('garb', 'brag'),
#  ('orb', 'bro'),
#  ('sorb', 'bros'),
#  ('tuber', 'rebut'),
#  ('dub', 'bud'),
#  ('nub', 'bun'),
#  ('snub', 'buns'),
#  ('rub', 'bur'),
#  ('drub', 'burd'),
#  ('grub', 'burg'),
#  ('suber', 'rebus'),
#  ('sub', 'bus'),
#  ('stub', 'buts'),
#  ('tub', 'but'),
#  ('mac', 'cam'),
#  ('scam', 'macs'),
#  ('pac', 'cap'),
#  ('recap', 'pacer'),
#  ('spacer', 'recaps'),
#  ('seracs', 'scares'),
#  ('pec', 'cep'),
#  ('spec', 'ceps'),
#  ('terces', 'secret'),
#  ('sic', 'cis'),
#  ('etic', 'cite'),
#  ('laced', 'decal'),
#  ('doc', 'cod'),
#  ('roc', 'cor'),
#  ('marc', 'cram'),
#  ('scram', 'marcs'),
#  ('gad', 'dag'),
#  ('had', 'dah'),
#  ('shad', 'dahs'),
#  ('lad', 'dal'),
#  ('mad', 'dam'),
#  ('pad', 'dap'),
#  ('trad', 'dart'),
#  ('tared', 'derat'),
#  ('stared', 'derats'),
#  ('wad', 'daw'),
#  ('ed', 'de'),
#  ('tubed', 'debut'),
#  ('faced', 'decaf'),
#  ('meed', 'deem'),
#  ('peed', 'deep'),
#  ('speed', 'deeps'),
#  ('reed', 'deer'),
#  ('seder', 'redes'),
#  ('seed', 'dees'),
#  ('teed', 'deet'),
#  ('steed', 'deets'),
#  ('refed', 'defer'),
#  ('imaged', 'degami'),
#  ('deified', 'deified'),
#  ('reified', 'deifier'),
#  ('lied', 'deil'),
#  ('eked', 'deke'),
#  ('led', 'del'),
#  ('fled', 'delf'),
#  ('reviled', 'deliver'),
#  ('sled', 'dels'),
#  ('timed', 'demit'),
#  ('reined', 'denier'),
#  ('seined', 'denies'),
#  ('mined', 'denim'),
#  ('sned', 'dens'),
#  ('toped', 'depot'),
#  ('stoped', 'depots'),
#  ('tressed', 'dessert'),
#  ('sexed', 'dexes'),
#  ('stressed', 'desserts'),
#  ('saved', 'devas'),
#  ('lived', 'devil'),
#  ('wed', 'dew'),
#  ('snawed', 'dewans'),
#  ('laid', 'dial'),
#  ('repaid', 'diaper'),
#  ('sedile', 'elides'),
#  ('tide', 'edit'),
#  ('gid', 'dig'),
#  ('mid', 'dim'),
#  ('ranid', 'dinar'),
#  ('sloid', 'diols'),
#  ('od', 'do'),
#  ('resod', 'doser'),
#  ('god', 'dog'),
#  ('mod', 'dom'),
#  ('nod', 'don'),
#  ('mood', 'doom'),
#  ('rood', 'door'),
#  ('rod', 'dor'),
#  ('nimrod', 'dormin'),
#  ('prod', 'dorp'),
#  ('sod', 'dos'),
#  ('tod', 'dot'),
#  ('liard', 'drail'),
#  ('ward', 'draw'),
#  ('reward', 'drawer'),
#  ('warder', 'redraw'),
#  ('sward', 'draws'),
#  ('yard', 'dray'),
#  ('leud', 'duel'),
#  ('oud', 'duo'),
#  ('pud', 'dup'),
#  ('spud', 'dups'),
#  ('elide', 'edile'),
#  ('lee', 'eel'),
#  ('seel', 'lees'),
#  ('he', 'eh'),
#  ('revel', 'lever'),
#  ('me', 'em'),
#  ('seme', 'emes'),
#  ('rime', 'emir'),
#  ('time', 'emit'),
#  ('stime', 'emits'),
#  ('ne', 'en'),
#  ('lone', 'enol'),
#  ('re', 'er'),
#  ('ere', 'ere'),
#  ('ogre', 'ergo'),
#  ('sore', 'eros'),
#  ('ser', 'res'),
#  ('seres', 'seres'),
#  ('livre', 'ervil'),
#  ('sees', 'sees'),
#  ('eve', 'eve'),
#  ('neve', 'even'),
#  ('seven', 'neves'),
#  ('live', 'evil'),
#  ('relive', 'eviler'),
#  ('ewe', 'ewe'),
#  ('ref', 'fer'),
#  ('reifier', 'reifier'),
#  ('rif', 'fir'),
#  ('serif', 'fires'),
#  ('golf', 'flog'),
#  ('wolf', 'flow'),
#  ('wolfer', 'reflow'),
#  ('loof', 'fool'),
#  ('refer', 'refer'),
#  ('lag', 'gal'),
#  ('slag', 'gals'),
#  ('mag', 'gam'),
#  ('nag', 'gan'),
#  ('rag', 'gar'),
#  ('sag', 'gas'),
#  ('stag', 'gats'),
#  ('tag', 'gat'),
#  ('nametag', 'gateman'),
#  ('leg', 'gel'),
#  ('redleg', 'gelder'),
#  ('teg', 'get'),
#  ('pig', 'gip'),
#  ('trig', 'girt'),
#  ('rang', 'gnar'),
#  ('tang', 'gnat'),
#  ('swang', 'gnaws'),
#  ('snug', 'guns'),
#  ('sung', 'gnus'),
#  ('prog', 'gorp'),
#  ('tog', 'got'),
#  ('lug', 'gul'),
#  ('plug', 'gulp'),
#  ('slug', 'guls'),
#  ('mug', 'gum'),
#  ('smug', 'gums'),
#  ('tug', 'gut'),
#  ('vug', 'guv'),
#  ('subah', 'habus'),
#  ('shah', 'hahs'),
#  ('selah', 'hales'),
#  ('pah', 'hap'),
#  ('shales', 'selahs'),
#  ('yah', 'hay'),
#  ('peh', 'hep'),
#  ('yeh', 'hey'),
#  ('oh', 'ho'),
#  ('noh', 'hon'),
#  ('pooh', 'hoop'),
#  ('poh', 'hop'),
#  ('nori', 'iron'),
#  ('si', 'is'),
#  ('sim', 'mis'),
#  ('ti', 'it'),
#  ('tis', 'sit'),
#  ('raj', 'jar'),
#  ('rank', 'knar'),
#  ('yak', 'kay'),
#  ('leek', 'keel'),
#  ('sleek', 'keels'),
#  ('peek', 'keep'),
#  ('steek', 'keets'),
#  ('spik', 'kips'),
#  ('shtik', 'kiths'),
#  ('spank', 'knaps'),
#  ('stink', 'knits'),
#  ('wonk', 'know'),
#  ('tarok', 'korat'),
#  ('mural', 'larum'),
#  ('reel', 'leer'),
#  ('teel', 'leet'),
#  ('teels', 'sleet'),
#  ('steel', 'leets'),
#  ('telfer', 'reflet'),
#  ('repel', 'leper'),
#  ('tel', 'let'),
#  ('snivel', 'levins'),
#  ('nil', 'lin'),
#  ('noil', 'lion'),
#  ('tils', 'slit'),
#  ('til', 'lit'),
#  ('tiler', 'relit'),
#  ('mool', 'loom'),
#  ('snool', 'loons'),
#  ('solon', 'nolos'),
#  ('pool', 'loop'),
#  ('spool', 'loops'),
#  ('sloop', 'pools'),
#  ('tool', 'loot'),
#  ('retool', 'looter'),
#  ('sotol', 'lotos'),
#  ('stool', 'loots'),
#  ('pol', 'lop'),
#  ('slop', 'pols'),
#  ('sulus', 'sulus'),
#  ('seam', 'maes'),
#  ('nam', 'man'),
#  ('tram', 'mart'),
#  ('trams', 'smart'),
#  ('tam', 'mat'),
#  ('swam', 'maws'),
#  ('yam', 'may'),
#  ('teem', 'meet'),
#  ('teemer', 'remeet'),
#  ('timer', 'remit'),
#  ('sememes', 'sememes'),
#  ('retem', 'meter'),
#  ('ohm', 'mho'),
#  ('slim', 'mils'),
#  ('rim', 'mir'),
#  ('om', 'mo'),
#  ('nom', 'mon'),
#  ('room', 'moor'),
#  ('toom', 'moot'),
#  ('pom', 'mop'),
#  ('rom', 'mor'),
#  ('tom', 'mot'),
#  ('notum', 'muton'),
#  ('um', 'mu'),
#  ('mum', 'mum'),
#  ('serum', 'mures'),
#  ('sum', 'mus'),
#  ('stum', 'muts'),
#  ('stums', 'smuts'),
#  ('reman', 'namer'),
#  ('pan', 'nap'),
#  ('snap', 'pans'),
#  ('span', 'naps'),
#  ('peen', 'neep'),
#  ('ten', 'net'),
#  ('wen', 'new'),
#  ('pin', 'nip'),
#  ('snip', 'pins'),
#  ('spin', 'nips'),
#  ('tin', 'nit'),
#  ('tins', 'snit'),
#  ('on', 'no'),
#  ('tenon', 'nonet'),
#  ('son', 'nos'),
#  ('ton', 'not'),
#  ('seton', 'notes'),
#  ('won', 'now'),
#  ('wons', 'snow'),
#  ('un', 'nu'),
#  ('sun', 'nus'),
#  ('tun', 'nut'),
#  ('stun', 'nuts'),
#  ('tao', 'oat'),
#  ('oho', 'oho'),
#  ('shoo', 'oohs'),
#  ('too', 'oot'),
#  ('top', 'pot'),
#  ('tops', 'spot'),
#  ('stop', 'pots'),
#  ('tor', 'rot'),
#  ('so', 'os'),
#  ('otto', 'otto'),
#  ('toot', 'toot'),
#  ('wo', 'ow'),
#  ('yo', 'oy'),
#  ('repaper', 'repaper'),
#  ('rap', 'par'),
#  ('spar', 'raps'),
#  ('tarp', 'prat'),
#  ('trap', 'part'),
#  ('tarps', 'sprat'),
#  ('strap', 'parts'),
#  ('taps', 'spat'),
#  ('wap', 'paw'),
#  ('swap', 'paws'),
#  ('yap', 'pay'),
#  ('yaps', 'spay'),
#  ('sleep', 'peels'),
#  ('seep', 'pees'),
#  ('rep', 'per'),
#  ('step', 'pets'),
#  ('sip', 'pis'),
#  ('tip', 'pit'),
#  ('tips', 'spit'),
#  ('snoop', 'poons'),
#  ('trop', 'port'),
#  ('strop', 'ports'),
#  ('stoper', 'repots'),
#  ('stops', 'spots'),
#  ('wop', 'pow'),
#  ('swop', 'pows'),
#  ('spider', 'redips'),
#  ('slipup', 'pupils'),
#  ('sirup', 'puris'),
#  ('sup', 'pus'),
#  ('tup', 'put'),
#  ('war', 'raw'),
#  ('yar', 'ray'),
#  ('rewarder', 'redrawer'),
#  ('seer', 'rees'),
#  ('tinker', 'reknit'),
#  ('stinker', 'reknits'),
#  ('tenner', 'rennet'),
#  ('sniper', 'repins'),
#  ('toper', 'repot'),
#  ('sorter', 'retros'),
#  ('stellas', 'sallets'),
#  ('soras', 'saros'),
#  ('tas', 'sat'),
#  ('was', 'saw'),
#  ('skees', 'seeks'),
#  ('semes', 'semes'),
#  ('tets', 'stet'),
#  ('stets', 'stets'),
#  ('sris', 'sirs'),
#  ('xis', 'six'),
#  ('steeks', 'skeets'),
#  ('spiks', 'skips'),
#  ('speels', 'sleeps'),
#  ('steels', 'sleets'),
#  ('spools', 'sloops'),
#  ('spans', 'snaps'),
#  ('swans', 'snaws'),
#  ('spins', 'snips'),
#  ('spoons', 'snoops'),
#  ('toons', 'snoot'),
#  ('tons', 'snot'),
#  ('wos', 'sow'),
#  ('zaps', 'spaz'),
#  ('trips', 'spirt'),
#  ('strips', 'spirts'),
#  ('stirps', 'sprits'),
#  ('strops', 'sports'),
#  ('tats', 'stat'),
#  ('taws', 'swat'),
#  ('wats', 'staw'),
#  ('wets', 'stew'),
#  ('tows', 'swot'),
#  ('wots', 'stow'),
#  ('swots', 'stows'),
#  ('warts', 'straw'),
#  ('worts', 'strow'),
#  ('sturts', 'struts'),
#  ('ulus', 'sulu'),
#  ('yaws', 'sway'),
#  ('vat', 'tav'),
#  ('wat', 'taw'),
#  ('wet', 'tew'),
#  ('trot', 'tort'),
#  ('wot', 'tow'),
#  ('wort', 'trow'),
#  ('yaw', 'way')]

# %%
list(itertools.combinations({1,2,3}, 2))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
pairs = []

for wordset in anagrams_by_sig.values():
    for word1, word2 in itertools.combinations(wordset, 2):
        if word1[::-1] == word2:
            pairs.append((word1, word2))

# %%
pairs
# Out:
# [('ab', 'ba'),
#  ('bas', 'sab'),
#  ('tuba', 'abut'),
#  ('serac', 'cares'),
#  ('laded', 'dedal'),
#  ('soda', 'ados'),
#  ('agar', 'raga'),
#  ('agas', 'saga'),
#  ('senega', 'agenes'),
#  ('ha', 'ah'),
#  ('redia', 'aider'),
#  ('sima', 'amis'),
#  ('ria', 'air'),
#  ('airts', 'stria'),
#  ('raja', 'ajar'),
#  ('al', 'la'),
#  ('lab', 'bal'),
#  ('bals', 'slab'),
#  ('alif', 'fila'),
#  ('lap', 'pal'),
#  ('pals', 'slap'),
#  ('las', 'sal'),
#  ('ma', 'am'),
#  ('amen', 'nema'),
#  ('animes', 'semina'),
#  ('pam', 'map'),
#  ('na', 'an'),
#  ('regna', 'anger'),
#  ('gnats', 'stang'),
#  ('lamina', 'animal'),
#  ('anon', 'nona'),
#  ('etna', 'ante'),
#  ('dopa', 'apod'),
#  ('pat', 'tap'),
#  ('bra', 'arb'),
#  ('are', 'era'),
#  ('sera', 'ares'),
#  ('lager', 'regal'),
#  ('aril', 'lira'),
#  ('rial', 'lair'),
#  ('rail', 'liar'),
#  ('dialer', 'relaid'),
#  ('lares', 'seral'),
#  ('ram', 'mar'),
#  ('arris', 'sirra'),
#  ('rat', 'tar'),
#  ('star', 'rats'),
#  ('arum', 'mura'),
#  ('sap', 'pas'),
#  ('saps', 'spas'),
#  ('at', 'ta'),
#  ('tae', 'eat'),
#  ('eta', 'ate'),
#  ('ates', 'seta'),
#  ('etas', 'sate'),
#  ('auks', 'skua'),
#  ('dual', 'laud'),
#  ('avid', 'diva'),
#  ('avo', 'ova'),
#  ('wan', 'naw'),
#  ('wans', 'snaw'),
#  ('ya', 'ay'),
#  ('dab', 'bad'),
#  ('bag', 'gab'),
#  ('ban', 'nab'),
#  ('brad', 'darb'),
#  ('drab', 'bard'),
#  ('stab', 'bats'),
#  ('bat', 'tab'),
#  ('bed', 'deb'),
#  ('neb', 'ben'),
#  ('dib', 'bid'),
#  ('big', 'gib'),
#  ('bin', 'nib'),
#  ('bins', 'snib'),
#  ('bird', 'drib'),
#  ('sib', 'bis'),
#  ('bulb', 'blub'),
#  ('gob', 'bog'),
#  ('lobo', 'obol'),
#  ('knob', 'bonk'),
#  ('bos', 'sob'),
#  ('stob', 'bots'),
#  ('swob', 'bows'),
#  ('boy', 'yob'),
#  ('garb', 'brag'),
#  ('orb', 'bro'),
#  ('bros', 'sorb'),
#  ('rebut', 'tuber'),
#  ('bud', 'dub'),
#  ('bun', 'nub'),
#  ('buns', 'snub'),
#  ('bur', 'rub'),
#  ('drub', 'burd'),
#  ('burg', 'grub'),
#  ('rebus', 'suber'),
#  ('sub', 'bus'),
#  ('stub', 'buts'),
#  ('tub', 'but'),
#  ('cam', 'mac'),
#  ('macs', 'scam'),
#  ('cap', 'pac'),
#  ('recap', 'pacer'),
#  ('recaps', 'spacer'),
#  ('seracs', 'scares'),
#  ('cep', 'pec'),
#  ('ceps', 'spec'),
#  ('secret', 'terces'),
#  ('sic', 'cis'),
#  ('etic', 'cite'),
#  ('laced', 'decal'),
#  ('doc', 'cod'),
#  ('roc', 'cor'),
#  ('cram', 'marc'),
#  ('marcs', 'scram'),
#  ('gad', 'dag'),
#  ('had', 'dah'),
#  ('dahs', 'shad'),
#  ('dal', 'lad'),
#  ('dam', 'mad'),
#  ('dap', 'pad'),
#  ('trad', 'dart'),
#  ('tared', 'derat'),
#  ('derats', 'stared'),
#  ('daw', 'wad'),
#  ('ed', 'de'),
#  ('tubed', 'debut'),
#  ('faced', 'decaf'),
#  ('meed', 'deem'),
#  ('deep', 'peed'),
#  ('speed', 'deeps'),
#  ('deer', 'reed'),
#  ('seder', 'redes'),
#  ('dees', 'seed'),
#  ('deet', 'teed'),
#  ('steed', 'deets'),
#  ('defer', 'refed'),
#  ('imaged', 'degami'),
#  ('reified', 'deifier'),
#  ('lied', 'deil'),
#  ('deke', 'eked'),
#  ('led', 'del'),
#  ('fled', 'delf'),
#  ('deliver', 'reviled'),
#  ('sled', 'dels'),
#  ('demit', 'timed'),
#  ('reined', 'denier'),
#  ('seined', 'denies'),
#  ('denim', 'mined'),
#  ('dens', 'sned'),
#  ('depot', 'toped'),
#  ('stoped', 'depots'),
#  ('tressed', 'dessert'),
#  ('sexed', 'dexes'),
#  ('stressed', 'desserts'),
#  ('devas', 'saved'),
#  ('lived', 'devil'),
#  ('dew', 'wed'),
#  ('snawed', 'dewans'),
#  ('laid', 'dial'),
#  ('diaper', 'repaid'),
#  ('elides', 'sedile'),
#  ('edit', 'tide'),
#  ('dig', 'gid'),
#  ('mid', 'dim'),
#  ('dinar', 'ranid'),
#  ('diols', 'sloid'),
#  ('od', 'do'),
#  ('doser', 'resod'),
#  ('god', 'dog'),
#  ('dom', 'mod'),
#  ('don', 'nod'),
#  ('mood', 'doom'),
#  ('door', 'rood'),
#  ('rod', 'dor'),
#  ('nimrod', 'dormin'),
#  ('dorp', 'prod'),
#  ('sod', 'dos'),
#  ('tod', 'dot'),
#  ('drail', 'liard'),
#  ('draw', 'ward'),
#  ('drawer', 'reward'),
#  ('redraw', 'warder'),
#  ('draws', 'sward'),
#  ('dray', 'yard'),
#  ('leud', 'duel'),
#  ('oud', 'duo'),
#  ('pud', 'dup'),
#  ('dups', 'spud'),
#  ('edile', 'elide'),
#  ('eel', 'lee'),
#  ('lees', 'seel'),
#  ('eh', 'he'),
#  ('lever', 'revel'),
#  ('me', 'em'),
#  ('seme', 'emes'),
#  ('rime', 'emir'),
#  ('time', 'emit'),
#  ('stime', 'emits'),
#  ('ne', 'en'),
#  ('enol', 'lone'),
#  ('er', 're'),
#  ('ogre', 'ergo'),
#  ('eros', 'sore'),
#  ('ser', 'res'),
#  ('ervil', 'livre'),
#  ('even', 'neve'),
#  ('seven', 'neves'),
#  ('evil', 'live'),
#  ('relive', 'eviler'),
#  ('fer', 'ref'),
#  ('rif', 'fir'),
#  ('fires', 'serif'),
#  ('flog', 'golf'),
#  ('wolf', 'flow'),
#  ('wolfer', 'reflow'),
#  ('loof', 'fool'),
#  ('lag', 'gal'),
#  ('slag', 'gals'),
#  ('mag', 'gam'),
#  ('gan', 'nag'),
#  ('gar', 'rag'),
#  ('sag', 'gas'),
#  ('gats', 'stag'),
#  ('tag', 'gat'),
#  ('nametag', 'gateman'),
#  ('gel', 'leg'),
#  ('redleg', 'gelder'),
#  ('teg', 'get'),
#  ('pig', 'gip'),
#  ('trig', 'girt'),
#  ('rang', 'gnar'),
#  ('gnat', 'tang'),
#  ('swang', 'gnaws'),
#  ('snug', 'guns'),
#  ('sung', 'gnus'),
#  ('gorp', 'prog'),
#  ('got', 'tog'),
#  ('lug', 'gul'),
#  ('plug', 'gulp'),
#  ('slug', 'guls'),
#  ('gum', 'mug'),
#  ('smug', 'gums'),
#  ('gut', 'tug'),
#  ('vug', 'guv'),
#  ('habus', 'subah'),
#  ('hahs', 'shah'),
#  ('hales', 'selah'),
#  ('pah', 'hap'),
#  ('shales', 'selahs'),
#  ('hay', 'yah'),
#  ('hep', 'peh'),
#  ('hey', 'yeh'),
#  ('oh', 'ho'),
#  ('noh', 'hon'),
#  ('pooh', 'hoop'),
#  ('hop', 'poh'),
#  ('nori', 'iron'),
#  ('is', 'si'),
#  ('sim', 'mis'),
#  ('it', 'ti'),
#  ('sit', 'tis'),
#  ('raj', 'jar'),
#  ('knar', 'rank'),
#  ('kay', 'yak'),
#  ('leek', 'keel'),
#  ('keels', 'sleek'),
#  ('peek', 'keep'),
#  ('keets', 'steek'),
#  ('kips', 'spik'),
#  ('shtik', 'kiths'),
#  ('knaps', 'spank'),
#  ('stink', 'knits'),
#  ('know', 'wonk'),
#  ('korat', 'tarok'),
#  ('mural', 'larum'),
#  ('reel', 'leer'),
#  ('teel', 'leet'),
#  ('teels', 'sleet'),
#  ('leets', 'steel'),
#  ('reflet', 'telfer'),
#  ('leper', 'repel'),
#  ('let', 'tel'),
#  ('levins', 'snivel'),
#  ('nil', 'lin'),
#  ('lion', 'noil'),
#  ('tils', 'slit'),
#  ('lit', 'til'),
#  ('relit', 'tiler'),
#  ('mool', 'loom'),
#  ('loons', 'snool'),
#  ('nolos', 'solon'),
#  ('pool', 'loop'),
#  ('loops', 'spool'),
#  ('pools', 'sloop'),
#  ('tool', 'loot'),
#  ('looter', 'retool'),
#  ('sotol', 'lotos'),
#  ('loots', 'stool'),
#  ('pol', 'lop'),
#  ('slop', 'pols'),
#  ('maes', 'seam'),
#  ('man', 'nam'),
#  ('tram', 'mart'),
#  ('smart', 'trams'),
#  ('mat', 'tam'),
#  ('maws', 'swam'),
#  ('yam', 'may'),
#  ('meet', 'teem'),
#  ('teemer', 'remeet'),
#  ('timer', 'remit'),
#  ('meter', 'retem'),
#  ('mho', 'ohm'),
#  ('slim', 'mils'),
#  ('rim', 'mir'),
#  ('om', 'mo'),
#  ('nom', 'mon'),
#  ('moor', 'room'),
#  ('moot', 'toom'),
#  ('mop', 'pom'),
#  ('rom', 'mor'),
#  ('mot', 'tom'),
#  ('notum', 'muton'),
#  ('mu', 'um'),
#  ('serum', 'mures'),
#  ('sum', 'mus'),
#  ('muts', 'stum'),
#  ('smuts', 'stums'),
#  ('namer', 'reman'),
#  ('nap', 'pan'),
#  ('naps', 'span'),
#  ('pans', 'snap'),
#  ('peen', 'neep'),
#  ('net', 'ten'),
#  ('new', 'wen'),
#  ('nip', 'pin'),
#  ('nips', 'spin'),
#  ('snip', 'pins'),
#  ('nit', 'tin'),
#  ('snit', 'tins'),
#  ('on', 'no'),
#  ('nonet', 'tenon'),
#  ('son', 'nos'),
#  ('ton', 'not'),
#  ('seton', 'notes'),
#  ('won', 'now'),
#  ('wons', 'snow'),
#  ('nu', 'un'),
#  ('sun', 'nus'),
#  ('nut', 'tun'),
#  ('nuts', 'stun'),
#  ('tao', 'oat'),
#  ('oohs', 'shoo'),
#  ('too', 'oot'),
#  ('pot', 'top'),
#  ('pots', 'stop'),
#  ('tops', 'spot'),
#  ('rot', 'tor'),
#  ('so', 'os'),
#  ('ow', 'wo'),
#  ('oy', 'yo'),
#  ('rap', 'par'),
#  ('spar', 'raps'),
#  ('prat', 'tarp'),
#  ('trap', 'part'),
#  ('tarps', 'sprat'),
#  ('strap', 'parts'),
#  ('spat', 'taps'),
#  ('wap', 'paw'),
#  ('swap', 'paws'),
#  ('yap', 'pay'),
#  ('spay', 'yaps'),
#  ('sleep', 'peels'),
#  ('pees', 'seep'),
#  ('per', 'rep'),
#  ('pets', 'step'),
#  ('pis', 'sip'),
#  ('tip', 'pit'),
#  ('tips', 'spit'),
#  ('snoop', 'poons'),
#  ('trop', 'port'),
#  ('strop', 'ports'),
#  ('stoper', 'repots'),
#  ('stops', 'spots'),
#  ('pow', 'wop'),
#  ('pows', 'swop'),
#  ('spider', 'redips'),
#  ('slipup', 'pupils'),
#  ('sirup', 'puris'),
#  ('pus', 'sup'),
#  ('tup', 'put'),
#  ('raw', 'war'),
#  ('yar', 'ray'),
#  ('redrawer', 'rewarder'),
#  ('rees', 'seer'),
#  ('tinker', 'reknit'),
#  ('stinker', 'reknits'),
#  ('rennet', 'tenner'),
#  ('sniper', 'repins'),
#  ('toper', 'repot'),
#  ('sorter', 'retros'),
#  ('sallets', 'stellas'),
#  ('soras', 'saros'),
#  ('tas', 'sat'),
#  ('saw', 'was'),
#  ('seeks', 'skees'),
#  ('tets', 'stet'),
#  ('sirs', 'sris'),
#  ('six', 'xis'),
#  ('skeets', 'steeks'),
#  ('spiks', 'skips'),
#  ('speels', 'sleeps'),
#  ('steels', 'sleets'),
#  ('spools', 'sloops'),
#  ('snaps', 'spans'),
#  ('snaws', 'swans'),
#  ('spins', 'snips'),
#  ('snoops', 'spoons'),
#  ('snoot', 'toons'),
#  ('snot', 'tons'),
#  ('sow', 'wos'),
#  ('spaz', 'zaps'),
#  ('trips', 'spirt'),
#  ('sprits', 'stirps'),
#  ('strips', 'spirts'),
#  ('strops', 'sports'),
#  ('tats', 'stat'),
#  ('taws', 'swat'),
#  ('staw', 'wats'),
#  ('stew', 'wets'),
#  ('stow', 'wots'),
#  ('swot', 'tows'),
#  ('swots', 'stows'),
#  ('warts', 'straw'),
#  ('worts', 'strow'),
#  ('struts', 'sturts'),
#  ('sulu', 'ulus'),
#  ('sway', 'yaws'),
#  ('tav', 'vat'),
#  ('taw', 'wat'),
#  ('wet', 'tew'),
#  ('tort', 'trot'),
#  ('wot', 'tow'),
#  ('wort', 'trow'),
#  ('way', 'yaw')]
